# %%
import os 
os.environ["CUDA_VISIBLE_DEVICES"] = "2" 
from keras.datasets import mnist
#import matplotlib
#%matplotlib inline
#import matplotlib.pyplot as plt
#import l2_attack
import keras
#from defense import *
import tensorflow as tf
import time
from torch.autograd import Variable
import torch
import numpy as np
from wrapper import Model
# Out:
# /home/yusu/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
class blackbox:
    def __init__(self,model):
        self.model = model
        
    def attack_untargeted(self, x0, y0, alpha = 4, beta = 0.005, iterations = 1000):
        """ Attack the original image and return adversarial example
            model: (pytorch model)
            alpha: learning rate 
            beta: learning rate
            train_dataset: set of training data
            (x0, y0): original image
        """
        pred = self.model.predict(x0)
        print("predicted label:", pred)
        print("true label:", y0)

#        if (self.model.predict(x0) != y0):
#            print("Fail to classify the image. No need to attack.")
#            return x0
    
        num_directions = 1000
        num_query = 10
        best_theta, g_theta = None, float('inf')
        query_count = 0
        comp_theta = 0
        current_best = float('inf')
        
        timestart = time.time()
        for i in range(num_directions):
            theta = torch.randn(x0.shape).type(torch.FloatTensor)
            initial_lbd = torch.norm(theta)
            theta = theta/torch.norm(theta)
            if self.model.predict(x0+np.array(initial_lbd*theta)) != y0:
                lbd,comp_dec = self.fine_grained_binary_search_fix(x0,y0,theta,initial_lbd,g_theta,current_best,num_query)
                if comp_dec > comp_theta:
                    comp_theta = comp_dec
                    best_theta,g_theta = theta,lbd
                    print("--------> Found abs-distortion %.4f with 10 queries" % g_theta)
                    print("--------> Found comp-distortion %.4f with 10 queries" % comp_dec)
            timeend = time.time()
        print("==========> Found best distortion %.4f in %.4f seconds" % (g_theta, timeend-timestart))
        query_count = (num_directions+1)*num_query
        #print("type of best_theta", type(best_theta))
        #print("type of best_theta", type(g_theta))
        lbd,count = self.fine_grained_binary_search( x0, y0, best_theta, g_theta, current_best)
        g_theta = lbd
        query_count += count
        
#        timestart = time.time()
#        for i in range(num_directions):
#            theta = torch.randn(x0.shape).type(torch.FloatTensor)
#            #print(theta.size())
#            initial_lbd = torch.norm(theta)
#            theta = theta/torch.norm(theta)
#            if self.model.predict(x0+np.array(initial_lbd*theta)) != y0:
#                query_count += 1 
#                #print(type(theta),type(initial_lbd),type(g_theta))
#                #print("find a new adv direction, new label:", self.model.predict(x0+np.array(initial_lbd*theta)))
#                lbd, count = self.fine_grained_binary_search( x0, y0, theta, initial_lbd, g_theta)
#                query_count += count
#                if lbd < g_theta:
#                    best_theta, g_theta = theta,lbd
##                    print("label for random direction:",self.model.predict(x0+np.array(g_theta*best_theta)))
#                    print("--------> Found distortion %.4f" % g_theta)
#        
#            timeend = time.time()
#            print("==========> Found best distortion %.4f in %.4f seconds using %d queries" % (g_theta, timeend-timestart, query_count))
        
        
        
        
    
        g1 = 1.0
        theta, g2 = best_theta.clone(), g_theta
        torch.manual_seed(0)
        opt_count = 0
        stopping = 0.01
        prev_obj = 100000
        for i in range(iterations):
 
            if g_theta < 1:
                print("====================query number after distortion < 1 =======================: ",opt_count)
                break
            gradient = torch.zeros(theta.size())
            q = 10
            min_g1 = float('inf')
            for j in range(q):
                u = torch.randn(theta.size()).type(torch.FloatTensor)
                u = u/torch.norm(u)
                ttt = theta+beta * u
                ttt = ttt/torch.norm(ttt)
                #print("inner loop iteration: ", j)
                g1, count = self.fine_grained_binary_search_local( x0, y0, ttt, initial_lbd = g2, tol=beta/500)
                opt_count += count
                gradient += (g1-g2)/beta * u
                if g1 < min_g1:
                    min_g1 = g1
                    min_ttt = ttt
            gradient = 1.0/q * gradient
#            print("=============================================")
    
            if (i+1)%50 == 0:
                
                print("Iteration %3d: g(theta + beta*u) = %.4f g(theta) = %.4f distortion %.4f num_queries %d" % (i+1, g1, g2, torch.norm(g2*theta), opt_count))
                if g2 > prev_obj-stopping:
                    break
                prev_obj = g2
    
            min_theta = theta
            min_g2 = g2
            

            for _ in range(15):
                new_theta = theta - alpha * gradient
                new_theta = new_theta/torch.norm(new_theta)
                new_g2, count = self.fine_grained_binary_search_local( x0, y0, new_theta, initial_lbd = min_g2, tol=beta/50)
                opt_count += count
                alpha = alpha * 2
#                print("alpha in the first for loop is: ",alpha)
                if new_g2 < min_g2:
                    min_theta = new_theta 
                    min_g2 = new_g2
                else:
                    break
#            print("=============================================")
    
            if min_g2 >= g2:
                for _ in range(15):
                    alpha = alpha * 0.5
                    new_theta = theta - alpha * gradient
                    new_theta = new_theta/torch.norm(new_theta)
                    new_g2, count = self.fine_grained_binary_search_local( x0, y0, new_theta, initial_lbd = min_g2, tol=beta/50)
                    opt_count += count
#                    print("alpha in the second for loop is: ",alpha)
                    if new_g2 < g2:
                        min_theta = new_theta 
                        min_g2 = new_g2
                        break
#            print("=============================================")
            if min_g2 <= min_g1:
                theta, g2 = min_theta, min_g2
            else:
                theta, g2 = min_ttt, min_g1
    
            if g2 < g_theta:
                best_theta, g_theta = theta.clone(), g2
            
            #print(alpha)
#            print("%3d th iteration" % i)
#            print("current alpha:",alpha)
#            print("g_theta")
#            print("number of queries:", opt_count+query_count)
            if alpha < 1e-4:
                alpha = 1.0
                print("Warning: not moving, g2 %lf gtheta %lf" % (g2, g_theta))
                beta = beta * 0.1
                if (beta < 1e-5):
                    print("beta is too samll")
                    break

    
        #target = model.predict(x0 + g_theta*best_theta)
        
        #print("\nAdversarial Example Found Successfully: distortion %.4f target %d queries %d \nTime: %.4f seconds" % (g_theta, target, query_count + opt_count, timeend-timestart))
        print("mnist_baseline")
        print("best distortion :", g_theta)
        print("number of queries :", opt_count+query_count)
        return x0 + np.array(g_theta*best_theta), opt_count+query_count
    def fine_grained_binary_search_local(self, x0, y0, theta, initial_lbd = 1.0, tol=1e-5):
        nquery = 0
        lbd = initial_lbd
        
        if self.model.predict(x0+np.array(lbd*theta)) == y0:
            lbd_lo = lbd
            lbd_hi = lbd*1.01
            nquery += 1
            #timestart1 = time.time()
            while self.model.predict(x0+np.array(lbd_hi*theta)) == y0:
                lbd_hi = lbd_hi*1.01
                nquery += 1
                if lbd_hi > 20:
                    return float('inf'), nquery
            #timeend1 = time.time()
#            print("1st while time:", timeend1 - timestart1)
        else:
            lbd_hi = lbd
            lbd_lo = lbd*0.99
            nquery += 1
            #timestart2 = time.time()
            while self.model.predict(x0+ np.array(lbd_lo*theta)) != y0 :
                lbd_lo = lbd_lo*0.99
                nquery += 1
            #timeend2 = time.time()
#            print("2nd while time:", timeend2 - timestart2)
            
        #timestart3 = time.time()
        while (lbd_hi - lbd_lo) > tol:
            lbd_mid = (lbd_lo + lbd_hi)/2.0
            nquery += 1
            if self.model.predict(x0 + np.array(lbd_mid*theta)) != y0:
                lbd_hi = lbd_mid
            else:
                lbd_lo = lbd_mid
        #timeend3 = time.time()
#        print("3rd while time:",timeend3 - timestart3)
#        print("lbd_low:",lbd_lo)
#        print("lbd_high:", lbd_hi)
#        print("-----------------------------")
        return lbd_hi, nquery
    
    def fine_grained_binary_search_fix(self,x0,y0,theta, initial_lbd = 1.0, tol=1e-5,current_best = float('inf'),num_query = 10):
        nquery = 0
        if initial_lbd > current_best: 
            if self.model.predict(x0+ np.array(current_best*theta)) == y0:
                nquery += 1
                return float('inf'), nquery
            lbd = current_best
        else:
            lbd = initial_lbd
    
        lbd_hi = lbd
        lbd_lo = 0.0
    
        while (lbd_hi - lbd_lo) > 1e-5:
            lbd_mid = (lbd_lo + lbd_hi)/2.0
            nquery += 1
            if self.model.predict(x0 + np.array(lbd_mid*theta)) != y0:
                lbd_hi = lbd_mid
            else:
                lbd_lo = lbd_mid
            if nquery > num_query:
                break
        comp_dec = (initial_lbd - lbd_hi)/initial_lbd
       # print("number of query before return for this direction:",nquery)
        return lbd_hi,comp_dec,
    
    def fine_grained_binary_search(self, x0, y0, theta, initial_lbd, current_best):
        nquery = 0
        if initial_lbd > current_best: 
            if self.model.predict(x0+ np.array(current_best*theta)) == y0:
                nquery += 1
                #print("initial_lbd > current_best & predict == y0, so return inf")
                return float('inf'), nquery
            lbd = current_best
        else:
            lbd = initial_lbd
            
        ## original version
        #lbd = initial_lbd
        #while model.predict(x0 + lbd*theta) == y0:
        #    lbd *= 2
        #    nquery += 1
        #    if lbd > 100:
        #        return float('inf'), nquery
        
        #num_intervals = 100
    
        # lambdas = np.linspace(0.0, lbd, num_intervals)[1:]
        # lbd_hi = lbd
        # lbd_hi_index = 0
        # for i, lbd in enumerate(lambdas):
        #     nquery += 1
        #     if model.predict(x0 + lbd*theta) != y0:
        #         lbd_hi = lbd
        #         lbd_hi_index = i
        #         break
    
        # lbd_lo = lambdas[lbd_hi_index - 1]
        lbd_hi = lbd
        lbd_lo = 0.
        print("label before fine binary search:", self.model.predict(x0+ np.array(lbd_hi*theta)))
    
        while (lbd_hi - lbd_lo) > 1e-3:
            lbd_mid = (lbd_lo + lbd_hi)/2.0
            nquery += 1
            if self.model.predict(x0 + np.array(lbd_mid*theta)) != y0:
                lbd_hi = lbd_mid
            else:
                lbd_lo = lbd_mid
        #print("find a better initialization")
        return lbd_hi, nquery

# %%
session = keras.backend.get_session()
keras.backend.set_learning_phase(False)
model = keras.models.load_model("data/mnist")
model = Model(model,[0.0,1.0])

attack = blackbox(model)

#touse = [x for x in tf.trainable_variables() if 'Generator' in x.name]
#saver = tf.train.Saver(touse)
#saver.restore(session, 'data/mnist-gan')

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_test = np.array(x_test, dtype=np.float32)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
x_test /= 255.0
#image = x_test[:1]
#adv = attack.attack_untargeted(image[0],y_test[0], alpha = 4, beta = 0.005, iterations = 1000)
count = []
for i in range(20):
    label = model.predict(x_test[i])
    if label == y_test[i]:
        count.append(1)
    else:
        count.append(0)
    
print("accuracy of this model is:", sum(count)/len(count))
# Out:
# accuracy of this model is: 0.95

# %%
dist = []
count = []
for i in range(15):
    print("=========================image ",i+1,"==========================================")
    print("true label:",y_test[i+20])
    print("predicted label:",model.predict(x_test[i+20]))
    adv, queries= attack.attack_untargeted(x_test[i+20],y_test[i+20], alpha = 4, beta = 0.005, iterations = 1000)
    res = adv - x_test[i+20]
    dist.append(np.linalg.norm(res))
    count.append(queries)

index = np.nonzero(count)
index = list(index)[0].tolist()

avg_distortion = np.mean(np.array(dist)[index])
avg_count = np.mean(np.array(count)[index])
print("the average distortion for %2d images :"%(len(index)),avg_distortion)
for i in dist:
    print(i)
print("the number of queries for %2d images :"%(len(index)), avg_count)
for j in count:
    print(j)
# Out:
# =========================image  1 ==========================================
# true label: 7
# predicted label: 7
# predicted label: 7
# true label: 7
# --------> Found abs-distortion 18.3811 with 10 queries
# --------> Found comp-distortion 0.3677 with 10 queries
# --------> Found abs-distortion 15.3953 with 10 queries
# --------> Found comp-distortion 0.4326 with 10 queries
# --------> Found abs-distortion 14.2115 with 10 queries
# --------> Found comp-distortion 0.4878 with 10 queries
# --------> Found abs-distortion 13.6948 with 10 queries
# --------> Found comp-distortion 0.5225 with 10 queries
# --------> Found abs-distortion 12.2772 with 10 queries
# --------> Found comp-distortion 0.5439 with 10 queries
# --------> Found abs-distortion 12.8522 with 10 queries
# --------> Found comp-distortion 0.5488 with 10 queries
# --------> Found abs-distortion 11.3428 with 10 queries
# --------> Found comp-distortion 0.5806 with 10 queries
# --------> Found abs-distortion 11.6388 with 10 queries
# --------> Found comp-distortion 0.5835 with 10 queries
# --------> Found abs-distortion 11.7165 with 10 queries
# --------> Found comp-distortion 0.5938 with 10 queries
# --------> Found abs-distortion 9.4281 with 10 queries
# --------> Found comp-distortion 0.6592 with 10 queries
# --------> Found abs-distortion 9.1855 with 10 queries
# --------> Found comp-distortion 0.6777 with 10 queries
# ==========> Found best distortion 9.1855 in 21.8552 seconds
# label before fine binary search: 3
# Iteration  50: g(theta + beta*u) = 2.9765 g(theta) = 2.9766 distortion 2.9766 num_queries 9701
# Iteration 100: g(theta + beta*u) = 2.2049 g(theta) = 2.2050 distortion 2.2050 num_queries 18146
# Iteration 150: g(theta + beta*u) = 1.9669 g(theta) = 1.9668 distortion 1.9668 num_queries 25966
# Iteration 200: g(theta + beta*u) = 1.8383 g(theta) = 1.8382 distortion 1.8382 num_queries 33347
# Iteration 250: g(theta + beta*u) = 1.7789 g(theta) = 1.7789 distortion 1.7789 num_queries 40718
# Iteration 300: g(theta + beta*u) = 1.7427 g(theta) = 1.7427 distortion 1.7427 num_queries 48072
# Iteration 350: g(theta + beta*u) = 1.7227 g(theta) = 1.7226 distortion 1.7226 num_queries 55440
# Warning: not moving, g2 1.711663 gtheta 1.711663
# Iteration 400: g(theta + beta*u) = 1.7117 g(theta) = 1.7117 distortion 1.7117 num_queries 63008
# Iteration 450: g(theta + beta*u) = 1.7022 g(theta) = 1.7022 distortion 1.7022 num_queries 72679
# mnist_baseline
# best distortion : tensor(1.7022)
# number of queries : 82703
# =========================image  2 ==========================================
# true label: 2
# predicted label: 2
# predicted label: 2
# true label: 2
# --------> Found abs-distortion 20.3640 with 10 queries
# --------> Found comp-distortion 0.2729 with 10 queries
# --------> Found abs-distortion 15.7466 with 10 queries
# --------> Found comp-distortion 0.4365 with 10 queries
# --------> Found abs-distortion 13.4468 with 10 queries
# --------> Found comp-distortion 0.5195 with 10 queries
# ==========> Found best distortion 13.4468 in 8.3019 seconds
# label before fine binary search: 8
# Iteration  50: g(theta + beta*u) = 4.2670 g(theta) = 4.2661 distortion 4.2661 num_queries 9974
# Iteration 100: g(theta + beta*u) = 3.3683 g(theta) = 3.3678 distortion 3.3678 num_queries 18429
# Iteration 150: g(theta + beta*u) = 2.9746 g(theta) = 2.9747 distortion 2.9747 num_queries 27103
# Iteration 200: g(theta + beta*u) = 2.7742 g(theta) = 2.7745 distortion 2.7745 num_queries 35367
# Iteration 250: g(theta + beta*u) = 2.6374 g(theta) = 2.6375 distortion 2.6375 num_queries 43533
# Iteration 300: g(theta + beta*u) = 2.5486 g(theta) = 2.5487 distortion 2.5487 num_queries 51659
# Iteration 350: g(theta + beta*u) = 2.4857 g(theta) = 2.4853 distortion 2.4853 num_queries 59600
# Iteration 400: g(theta + beta*u) = 2.4489 g(theta) = 2.4489 distortion 2.4489 num_queries 67473
# Iteration 450: g(theta + beta*u) = 2.4240 g(theta) = 2.4241 distortion 2.4241 num_queries 75308
# Warning: not moving, g2 2.413498 gtheta 2.413498
# Iteration 500: g(theta + beta*u) = 2.4096 g(theta) = 2.4096 distortion 2.4096 num_queries 83921
# Iteration 550: g(theta + beta*u) = 2.3962 g(theta) = 2.3961 distortion 2.3961 num_queries 93845
# Iteration 600: g(theta + beta*u) = 2.3855 g(theta) = 2.3855 distortion 2.3855 num_queries 103769
# Iteration 650: g(theta + beta*u) = 2.3782 g(theta) = 2.3782 distortion 2.3782 num_queries 113628
# mnist_baseline
# best distortion : tensor(2.3782)
# number of queries : 123652
# =========================image  3 ==========================================
# true label: 1
# predicted label: 1
# predicted label: 1
# true label: 1
# --------> Found abs-distortion 9.6456 with 10 queries
# --------> Found comp-distortion 0.6675 with 10 queries
# --------> Found abs-distortion 8.3481 with 10 queries
# --------> Found comp-distortion 0.7002 with 10 queries
# --------> Found abs-distortion 7.4150 with 10 queries
# --------> Found comp-distortion 0.7388 with 10 queries
# --------> Found abs-distortion 6.3890 with 10 queries
# --------> Found comp-distortion 0.7617 with 10 queries
# ==========> Found best distortion 6.3890 in 22.0471 seconds
# label before fine binary search: 2
# Iteration  50: g(theta + beta*u) = 2.5554 g(theta) = 2.5544 distortion 2.5544 num_queries 9316
# Iteration 100: g(theta + beta*u) = 1.9754 g(theta) = 1.9750 distortion 1.9750 num_queries 17416
# Iteration 150: g(theta + beta*u) = 1.7911 g(theta) = 1.7912 distortion 1.7912 num_queries 25092
# Iteration 200: g(theta + beta*u) = 1.6647 g(theta) = 1.6649 distortion 1.6649 num_queries 32525
# Iteration 250: g(theta + beta*u) = 1.5959 g(theta) = 1.5961 distortion 1.5961 num_queries 39930
# Iteration 300: g(theta + beta*u) = 1.5521 g(theta) = 1.5521 distortion 1.5521 num_queries 47251
# Iteration 350: g(theta + beta*u) = 1.5283 g(theta) = 1.5281 distortion 1.5281 num_queries 54583
# Iteration 400: g(theta + beta*u) = 1.5073 g(theta) = 1.5072 distortion 1.5072 num_queries 61951
# Warning: not moving, g2 1.505863 gtheta 1.505863
# Iteration 450: g(theta + beta*u) = 1.4968 g(theta) = 1.4968 distortion 1.4968 num_queries 71263
# Iteration 500: g(theta + beta*u) = 1.4882 g(theta) = 1.4882 distortion 1.4882 num_queries 80587
# mnist_baseline
# best distortion : tensor(1.4882)
# number of queries : 90610
# =========================image  4 ==========================================
# true label: 0
# predicted label: 0
# predicted label: 0
# true label: 0
# --------> Found abs-distortion 25.7958 with 10 queries
# --------> Found comp-distortion 0.0732 with 10 queries
# --------> Found abs-distortion 24.6946 with 10 queries
# --------> Found comp-distortion 0.1372 with 10 queries
# --------> Found abs-distortion 16.6537 with 10 queries
# --------> Found comp-distortion 0.3955 with 10 queries
# --------> Found abs-distortion 12.4171 with 10 queries
# --------> Found comp-distortion 0.5571 with 10 queries
# --------> Found abs-distortion 10.2912 with 10 queries
# --------> Found comp-distortion 0.6606 with 10 queries
# ==========> Found best distortion 10.2912 in 21.1945 seconds
# label before fine binary search: 8
# Iteration  50: g(theta + beta*u) = 3.7808 g(theta) = 3.7786 distortion 3.7786 num_queries 9766
# Iteration 100: g(theta + beta*u) = 2.8547 g(theta) = 2.8552 distortion 2.8552 num_queries 18538
# Iteration 150: g(theta + beta*u) = 2.5483 g(theta) = 2.5483 distortion 2.5483 num_queries 26756
# Iteration 200: g(theta + beta*u) = 2.3842 g(theta) = 2.3841 distortion 2.3841 num_queries 34726
# Iteration 250: g(theta + beta*u) = 2.3056 g(theta) = 2.3058 distortion 2.3058 num_queries 42655
# Iteration 300: g(theta + beta*u) = 2.2613 g(theta) = 2.2613 distortion 2.2613 num_queries 50560
# Iteration 350: g(theta + beta*u) = 2.2382 g(theta) = 2.2382 distortion 2.2382 num_queries 58516
# Warning: not moving, g2 2.238053 gtheta 2.238053
# Iteration 400: g(theta + beta*u) = 2.2219 g(theta) = 2.2219 distortion 2.2219 num_queries 68575
# Iteration 450: g(theta + beta*u) = 2.2101 g(theta) = 2.2102 distortion 2.2102 num_queries 78473
# Iteration 500: g(theta + beta*u) = 2.2027 g(theta) = 2.2027 distortion 2.2027 num_queries 88397
# mnist_baseline
# best distortion : tensor(2.2027)
# number of queries : 98421
# =========================image  5 ==========================================
# true label: 4
# predicted label: 4
# predicted label: 4
# true label: 4
# --------> Found abs-distortion 13.7677 with 10 queries
# --------> Found comp-distortion 0.5054 with 10 queries
# --------> Found abs-distortion 11.1776 with 10 queries
# --------> Found comp-distortion 0.6108 with 10 queries
# --------> Found abs-distortion 10.8315 with 10 queries
# --------> Found comp-distortion 0.6118 with 10 queries
# --------> Found abs-distortion 11.0576 with 10 queries
# --------> Found comp-distortion 0.6177 with 10 queries
# --------> Found abs-distortion 10.3953 with 10 queries
# --------> Found comp-distortion 0.6519 with 10 queries
# --------> Found abs-distortion 7.4414 with 10 queries
# --------> Found comp-distortion 0.7393 with 10 queries
# ==========> Found best distortion 7.4414 in 21.4075 seconds
# label before fine binary search: 9
# Iteration  50: g(theta + beta*u) = 2.0122 g(theta) = 2.0123 distortion 2.0123 num_queries 9656
# Iteration 100: g(theta + beta*u) = 1.5486 g(theta) = 1.5483 distortion 1.5483 num_queries 18121
# Iteration 150: g(theta + beta*u) = 1.3433 g(theta) = 1.3438 distortion 1.3438 num_queries 25923
# Iteration 200: g(theta + beta*u) = 1.2382 g(theta) = 1.2381 distortion 1.2381 num_queries 33393
# Iteration 250: g(theta + beta*u) = 1.1854 g(theta) = 1.1856 distortion 1.1856 num_queries 40705
# Warning: not moving, g2 1.168607 gtheta 1.168607
# Iteration 300: g(theta + beta*u) = 1.1606 g(theta) = 1.1606 distortion 1.1606 num_queries 48915
# Iteration 350: g(theta + beta*u) = 1.1405 g(theta) = 1.1405 distortion 1.1405 num_queries 58203
# Iteration 400: g(theta + beta*u) = 1.1290 g(theta) = 1.1290 distortion 1.1290 num_queries 67513
# Iteration 450: g(theta + beta*u) = 1.1214 g(theta) = 1.1214 distortion 1.1214 num_queries 76805
# mnist_baseline
# best distortion : tensor(1.1214)
# number of queries : 86828
# =========================image  6 ==========================================
# true label: 1
# predicted label: 1
# predicted label: 1
# true label: 1
# --------> Found abs-distortion 11.2419 with 10 queries
# --------> Found comp-distortion 0.5986 with 10 queries
# --------> Found abs-distortion 10.5961 with 10 queries
# --------> Found comp-distortion 0.6187 with 10 queries
# --------> Found abs-distortion 9.6199 with 10 queries
# --------> Found comp-distortion 0.6558 with 10 queries
# --------> Found abs-distortion 9.1234 with 10 queries
# --------> Found comp-distortion 0.6709 with 10 queries
# --------> Found abs-distortion 8.1782 with 10 queries
# --------> Found comp-distortion 0.6963 with 10 queries
# --------> Found abs-distortion 7.8076 with 10 queries
# --------> Found comp-distortion 0.7256 with 10 queries
# --------> Found abs-distortion 7.5042 with 10 queries
# --------> Found comp-distortion 0.7261 with 10 queries
# --------> Found abs-distortion 7.7192 with 10 queries
# --------> Found comp-distortion 0.7305 with 10 queries
# --------> Found abs-distortion 7.3297 with 10 queries
# --------> Found comp-distortion 0.7583 with 10 queries
# ==========> Found best distortion 7.3297 in 21.7879 seconds
# label before fine binary search: 8
# Iteration  50: g(theta + beta*u) = 2.3723 g(theta) = 2.3724 distortion 2.3724 num_queries 9607
# Iteration 100: g(theta + beta*u) = 1.9189 g(theta) = 1.9188 distortion 1.9188 num_queries 17507
# Iteration 150: g(theta + beta*u) = 1.7493 g(theta) = 1.7493 distortion 1.7493 num_queries 25248
# Iteration 200: g(theta + beta*u) = 1.6569 g(theta) = 1.6567 distortion 1.6567 num_queries 32923
# Iteration 250: g(theta + beta*u) = 1.5911 g(theta) = 1.5914 distortion 1.5914 num_queries 40387
# Iteration 300: g(theta + beta*u) = 1.5521 g(theta) = 1.5523 distortion 1.5523 num_queries 47786
# Iteration 350: g(theta + beta*u) = 1.5204 g(theta) = 1.5204 distortion 1.5204 num_queries 55086
# Iteration 400: g(theta + beta*u) = 1.5000 g(theta) = 1.4998 distortion 1.4998 num_queries 62445
# Warning: not moving, g2 1.492728 gtheta 1.492728
# Iteration 450: g(theta + beta*u) = 1.4882 g(theta) = 1.4882 distortion 1.4882 num_queries 70878
# Iteration 500: g(theta + beta*u) = 1.4803 g(theta) = 1.4803 distortion 1.4803 num_queries 80250
# mnist_baseline
# best distortion : tensor(1.4803)
# number of queries : 90273
# =========================image  7 ==========================================
# true label: 4
# predicted label: 4
# predicted label: 4
# true label: 4
# --------> Found abs-distortion 8.3449 with 10 queries
# --------> Found comp-distortion 0.7002 with 10 queries
# --------> Found abs-distortion 6.6857 with 10 queries
# --------> Found comp-distortion 0.7573 with 10 queries
# --------> Found abs-distortion 6.6551 with 10 queries
# --------> Found comp-distortion 0.7603 with 10 queries
# --------> Found abs-distortion 6.3848 with 10 queries
# --------> Found comp-distortion 0.7666 with 10 queries
# --------> Found abs-distortion 6.9447 with 10 queries
# --------> Found comp-distortion 0.7710 with 10 queries
# --------> Found abs-distortion 6.4598 with 10 queries
# --------> Found comp-distortion 0.7769 with 10 queries
# --------> Found abs-distortion 5.9555 with 10 queries
# --------> Found comp-distortion 0.7886 with 10 queries
# --------> Found abs-distortion 5.2653 with 10 queries
# --------> Found comp-distortion 0.8110 with 10 queries
# --------> Found abs-distortion 5.1664 with 10 queries
# --------> Found comp-distortion 0.8135 with 10 queries
# ==========> Found best distortion 5.1664 in 21.8871 seconds
# label before fine binary search: 8
# Iteration  50: g(theta + beta*u) = 1.5263 g(theta) = 1.5263 distortion 1.5263 num_queries 9146
# Iteration 100: g(theta + beta*u) = 1.1764 g(theta) = 1.1767 distortion 1.1767 num_queries 16969
# Iteration 150: g(theta + beta*u) = 1.0516 g(theta) = 1.0520 distortion 1.0520 num_queries 24326
# ====================query number after distortion < 1 =======================:  29167
# mnist_baseline
# best distortion : tensor(0.9995)
# number of queries : 39190
# =========================image  8 ==========================================
# true label: 9
# predicted label: 9
# predicted label: 9
# true label: 9
# --------> Found abs-distortion 11.6115 with 10 queries
# --------> Found comp-distortion 0.5854 with 10 queries
# --------> Found abs-distortion 11.1714 with 10 queries
# --------> Found comp-distortion 0.6089 with 10 queries
# --------> Found abs-distortion 9.9518 with 10 queries
# --------> Found comp-distortion 0.6445 with 10 queries
# --------> Found abs-distortion 8.6416 with 10 queries
# --------> Found comp-distortion 0.6919 with 10 queries
# --------> Found abs-distortion 8.8375 with 10 queries
# --------> Found comp-distortion 0.7002 with 10 queries
# --------> Found abs-distortion 8.6095 with 10 queries
# --------> Found comp-distortion 0.7021 with 10 queries
# --------> Found abs-distortion 7.7780 with 10 queries
# --------> Found comp-distortion 0.7202 with 10 queries
# --------> Found abs-distortion 7.0928 with 10 queries
# --------> Found comp-distortion 0.7461 with 10 queries
# --------> Found abs-distortion 6.5870 with 10 queries
# --------> Found comp-distortion 0.7715 with 10 queries
# ==========> Found best distortion 6.5870 in 22.3575 seconds
# label before fine binary search: 8
# Iteration  50: g(theta + beta*u) = 2.1584 g(theta) = 2.1584 distortion 2.1584 num_queries 9198
# Iteration 100: g(theta + beta*u) = 1.7568 g(theta) = 1.7568 distortion 1.7568 num_queries 17484
# Iteration 150: g(theta + beta*u) = 1.5548 g(theta) = 1.5544 distortion 1.5544 num_queries 25405
# Iteration 200: g(theta + beta*u) = 1.4318 g(theta) = 1.4319 distortion 1.4319 num_queries 33087
# Iteration 250: g(theta + beta*u) = 1.3591 g(theta) = 1.3590 distortion 1.3590 num_queries 40620
# Iteration 300: g(theta + beta*u) = 1.3275 g(theta) = 1.3277 distortion 1.3277 num_queries 47999
# Iteration 350: g(theta + beta*u) = 1.3066 g(theta) = 1.3065 distortion 1.3065 num_queries 55367
# Iteration 400: g(theta + beta*u) = 1.2934 g(theta) = 1.2933 distortion 1.2933 num_queries 62704
# Warning: not moving, g2 1.286493 gtheta 1.286493
# Iteration 450: g(theta + beta*u) = 1.2834 g(theta) = 1.2834 distortion 1.2834 num_queries 70944
# mnist_baseline
# best distortion : tensor(1.2834)
# number of queries : 80967
# =========================image  9 ==========================================
# true label: 5
# predicted label: 5
# predicted label: 5
# true label: 5
# --------> Found abs-distortion 17.4747 with 10 queries
# --------> Found comp-distortion 0.3711 with 10 queries
# --------> Found abs-distortion 9.5653 with 10 queries
# --------> Found comp-distortion 0.6577 with 10 queries
# --------> Found abs-distortion 7.2715 with 10 queries
# --------> Found comp-distortion 0.7441 with 10 queries
# --------> Found abs-distortion 7.0734 with 10 queries
# --------> Found comp-distortion 0.7476 with 10 queries
# --------> Found abs-distortion 5.7814 with 10 queries
# --------> Found comp-distortion 0.7969 with 10 queries
# --------> Found abs-distortion 4.8965 with 10 queries
# --------> Found comp-distortion 0.8252 with 10 queries
# --------> Found abs-distortion 4.6370 with 10 queries
# --------> Found comp-distortion 0.8340 with 10 queries
# ==========> Found best distortion 4.6370 in 20.4562 seconds
# label before fine binary search: 6
# ====================query number after distortion < 1 =======================:  7996
# mnist_baseline
# best distortion : tensor(0.9996)
# number of queries : 18019
# =========================image  10 ==========================================
# true label: 9
# predicted label: 9
# predicted label: 9
# true label: 9
# --------> Found abs-distortion 14.4217 with 10 queries
# --------> Found comp-distortion 0.4902 with 10 queries
# --------> Found abs-distortion 10.9307 with 10 queries
# --------> Found comp-distortion 0.5991 with 10 queries
# --------> Found abs-distortion 11.3550 with 10 queries
# --------> Found comp-distortion 0.6074 with 10 queries
# --------> Found abs-distortion 10.8789 with 10 queries
# --------> Found comp-distortion 0.6079 with 10 queries
# --------> Found abs-distortion 10.2578 with 10 queries
# --------> Found comp-distortion 0.6367 with 10 queries
# --------> Found abs-distortion 9.5656 with 10 queries
# --------> Found comp-distortion 0.6602 with 10 queries
# --------> Found abs-distortion 9.3952 with 10 queries
# --------> Found comp-distortion 0.6714 with 10 queries
# --------> Found abs-distortion 8.8257 with 10 queries
# --------> Found comp-distortion 0.6880 with 10 queries
# --------> Found abs-distortion 8.6592 with 10 queries
# --------> Found comp-distortion 0.6919 with 10 queries
# --------> Found abs-distortion 8.5375 with 10 queries
# --------> Found comp-distortion 0.6934 with 10 queries
# --------> Found abs-distortion 8.2152 with 10 queries
# --------> Found comp-distortion 0.7070 with 10 queries
# ==========> Found best distortion 8.2152 in 21.7511 seconds
# label before fine binary search: 8
# Iteration  50: g(theta + beta*u) = 2.6540 g(theta) = 2.6545 distortion 2.6545 num_queries 9495
# Iteration 100: g(theta + beta*u) = 2.0982 g(theta) = 2.0983 distortion 2.0983 num_queries 17712
# Iteration 150: g(theta + beta*u) = 1.9077 g(theta) = 1.9075 distortion 1.9075 num_queries 25448
# Iteration 200: g(theta + beta*u) = 1.8128 g(theta) = 1.8127 distortion 1.8127 num_queries 32842
# Iteration 250: g(theta + beta*u) = 1.7485 g(theta) = 1.7485 distortion 1.7485 num_queries 40340
# Iteration 300: g(theta + beta*u) = 1.7094 g(theta) = 1.7092 distortion 1.7092 num_queries 47688
# Iteration 350: g(theta + beta*u) = 1.6800 g(theta) = 1.6800 distortion 1.6800 num_queries 55032
# Warning: not moving, g2 1.669115 gtheta 1.669115
# Iteration 400: g(theta + beta*u) = 1.6637 g(theta) = 1.6637 distortion 1.6637 num_queries 63647
# Iteration 450: g(theta + beta*u) = 1.6503 g(theta) = 1.6503 distortion 1.6503 num_queries 73238
# Iteration 500: g(theta + beta*u) = 1.6416 g(theta) = 1.6416 distortion 1.6416 num_queries 82836
# mnist_baseline
# best distortion : tensor(1.6416)
# number of queries : 92860
# =========================image  11 ==========================================
# true label: 0
# predicted label: 0
# predicted label: 0
# true label: 0
# --------> Found abs-distortion 21.6370 with 10 queries
# --------> Found comp-distortion 0.2227 with 10 queries
# --------> Found abs-distortion 21.8855 with 10 queries
# --------> Found comp-distortion 0.2354 with 10 queries
# --------> Found abs-distortion 19.7476 with 10 queries
# --------> Found comp-distortion 0.2832 with 10 queries
# --------> Found abs-distortion 12.6224 with 10 queries
# --------> Found comp-distortion 0.5498 with 10 queries
# --------> Found abs-distortion 11.7723 with 10 queries
# --------> Found comp-distortion 0.5596 with 10 queries
# --------> Found abs-distortion 10.7225 with 10 queries
# --------> Found comp-distortion 0.6157 with 10 queries
# --------> Found abs-distortion 10.4638 with 10 queries
# --------> Found comp-distortion 0.6270 with 10 queries
# --------> Found abs-distortion 10.8243 with 10 queries
# --------> Found comp-distortion 0.6431 with 10 queries
# --------> Found abs-distortion 9.5135 with 10 queries
# --------> Found comp-distortion 0.6738 with 10 queries
# ==========> Found best distortion 9.5135 in 21.8466 seconds
# label before fine binary search: 8
# Iteration  50: g(theta + beta*u) = 3.9773 g(theta) = 3.9771 distortion 3.9771 num_queries 9514
# Iteration 100: g(theta + beta*u) = 3.1664 g(theta) = 3.1655 distortion 3.1655 num_queries 18316
# Iteration 150: g(theta + beta*u) = 2.7207 g(theta) = 2.7207 distortion 2.7207 num_queries 26765
# Iteration 200: g(theta + beta*u) = 2.5352 g(theta) = 2.5352 distortion 2.5352 num_queries 34876
# Iteration 250: g(theta + beta*u) = 2.4170 g(theta) = 2.4170 distortion 2.4170 num_queries 42846
# Iteration 300: g(theta + beta*u) = 2.3576 g(theta) = 2.3575 distortion 2.3575 num_queries 50758
# Iteration 350: g(theta + beta*u) = 2.3263 g(theta) = 2.3264 distortion 2.3264 num_queries 58598
# Warning: not moving, g2 2.317006 gtheta 2.317006
# Iteration 400: g(theta + beta*u) = 2.3045 g(theta) = 2.3045 distortion 2.3045 num_queries 68141
# Iteration 450: g(theta + beta*u) = 2.2880 g(theta) = 2.2880 distortion 2.2880 num_queries 78094
# Iteration 500: g(theta + beta*u) = 2.2795 g(theta) = 2.2795 distortion 2.2795 num_queries 88005
# mnist_baseline
# best distortion : tensor(2.2795)
# number of queries : 98029
# =========================image  12 ==========================================
# true label: 6
# predicted label: 6
# predicted label: 6
# true label: 6
# --------> Found abs-distortion 21.2700 with 10 queries
# --------> Found comp-distortion 0.2358 with 10 queries
# --------> Found abs-distortion 15.2891 with 10 queries
# --------> Found comp-distortion 0.4658 with 10 queries
# --------> Found abs-distortion 14.6782 with 10 queries
# --------> Found comp-distortion 0.4780 with 10 queries
# --------> Found abs-distortion 13.0877 with 10 queries
# --------> Found comp-distortion 0.5244 with 10 queries
# --------> Found abs-distortion 13.2852 with 10 queries
# --------> Found comp-distortion 0.5264 with 10 queries
# --------> Found abs-distortion 13.4047 with 10 queries
# --------> Found comp-distortion 0.5283 with 10 queries
# --------> Found abs-distortion 12.6900 with 10 queries
# --------> Found comp-distortion 0.5815 with 10 queries
# --------> Found abs-distortion 11.1333 with 10 queries
# --------> Found comp-distortion 0.6001 with 10 queries
# --------> Found abs-distortion 11.0434 with 10 queries
# --------> Found comp-distortion 0.6016 with 10 queries
# --------> Found abs-distortion 10.1999 with 10 queries
# --------> Found comp-distortion 0.6260 with 10 queries
# --------> Found abs-distortion 10.7924 with 10 queries
# --------> Found comp-distortion 0.6313 with 10 queries
# --------> Found abs-distortion 10.1062 with 10 queries
# --------> Found comp-distortion 0.6445 with 10 queries
# ==========> Found best distortion 10.1062 in 21.3674 seconds
# label before fine binary search: 8
# Iteration  50: g(theta + beta*u) = 3.7550 g(theta) = 3.7559 distortion 3.7559 num_queries 9948
# Iteration 100: g(theta + beta*u) = 2.7576 g(theta) = 2.7572 distortion 2.7572 num_queries 18661
# Iteration 150: g(theta + beta*u) = 2.4136 g(theta) = 2.4140 distortion 2.4140 num_queries 26790
# Iteration 200: g(theta + beta*u) = 2.2605 g(theta) = 2.2603 distortion 2.2603 num_queries 34724
# Iteration 250: g(theta + beta*u) = 2.1916 g(theta) = 2.1918 distortion 2.1918 num_queries 42594
# Iteration 300: g(theta + beta*u) = 2.1501 g(theta) = 2.1499 distortion 2.1499 num_queries 50448
# Warning: not moving, g2 2.135005 gtheta 2.135005
# Iteration 350: g(theta + beta*u) = 2.1291 g(theta) = 2.1291 distortion 2.1291 num_queries 59158
# Iteration 400: g(theta + beta*u) = 2.1132 g(theta) = 2.1132 distortion 2.1132 num_queries 69108
# Iteration 450: g(theta + beta*u) = 2.1035 g(theta) = 2.1035 distortion 2.1035 num_queries 79058
# mnist_baseline
# best distortion : tensor(2.1035)
# number of queries : 89082
# =========================image  13 ==========================================
# true label: 9
# predicted label: 9
# predicted label: 9
# true label: 9
# --------> Found abs-distortion 15.7824 with 10 queries
# --------> Found comp-distortion 0.4365 with 10 queries
# --------> Found abs-distortion 10.7798 with 10 queries
# --------> Found comp-distortion 0.6143 with 10 queries
# --------> Found abs-distortion 9.9643 with 10 queries
# --------> Found comp-distortion 0.6499 with 10 queries
# --------> Found abs-distortion 9.0302 with 10 queries
# --------> Found comp-distortion 0.6689 with 10 queries
# --------> Found abs-distortion 8.6954 with 10 queries
# --------> Found comp-distortion 0.6782 with 10 queries
# --------> Found abs-distortion 8.6639 with 10 queries
# --------> Found comp-distortion 0.6831 with 10 queries
# --------> Found abs-distortion 8.9368 with 10 queries
# --------> Found comp-distortion 0.6973 with 10 queries
# --------> Found abs-distortion 8.5252 with 10 queries
# --------> Found comp-distortion 0.7017 with 10 queries
# --------> Found abs-distortion 8.2465 with 10 queries
# --------> Found comp-distortion 0.7070 with 10 queries
# --------> Found abs-distortion 7.8450 with 10 queries
# --------> Found comp-distortion 0.7261 with 10 queries
# --------> Found abs-distortion 7.2781 with 10 queries
# --------> Found comp-distortion 0.7393 with 10 queries
# --------> Found abs-distortion 6.5436 with 10 queries
# --------> Found comp-distortion 0.7612 with 10 queries
# ==========> Found best distortion 6.5436 in 22.0500 seconds
# label before fine binary search: 4
# Iteration  50: g(theta + beta*u) = 1.7970 g(theta) = 1.7976 distortion 1.7976 num_queries 9166
# Iteration 100: g(theta + beta*u) = 1.3867 g(theta) = 1.3866 distortion 1.3866 num_queries 17485
# Iteration 150: g(theta + beta*u) = 1.2140 g(theta) = 1.2140 distortion 1.2140 num_queries 25092
# Iteration 200: g(theta + beta*u) = 1.1362 g(theta) = 1.1361 distortion 1.1361 num_queries 32452
# Iteration 250: g(theta + beta*u) = 1.0992 g(theta) = 1.0993 distortion 1.0993 num_queries 39732
# Iteration 300: g(theta + beta*u) = 1.0762 g(theta) = 1.0762 distortion 1.0762 num_queries 46968
# Warning: not moving, g2 1.065308 gtheta 1.065308
# Iteration 350: g(theta + beta*u) = 1.0639 g(theta) = 1.0639 distortion 1.0639 num_queries 54702
# Iteration 400: g(theta + beta*u) = 1.0545 g(theta) = 1.0545 distortion 1.0545 num_queries 64046
# mnist_baseline
# best distortion : tensor(1.0545)
# number of queries : 74069
# =========================image  14 ==========================================
# true label: 0
# predicted label: 0
# predicted label: 0
# true label: 0
# --------> Found abs-distortion 20.7501 with 10 queries
# --------> Found comp-distortion 0.2646 with 10 queries
# --------> Found abs-distortion 17.7033 with 10 queries
# --------> Found comp-distortion 0.3608 with 10 queries
# --------> Found abs-distortion 16.1272 with 10 queries
# --------> Found comp-distortion 0.4312 with 10 queries
# --------> Found abs-distortion 11.3378 with 10 queries
# --------> Found comp-distortion 0.5996 with 10 queries
# --------> Found abs-distortion 11.2037 with 10 queries
# --------> Found comp-distortion 0.6074 with 10 queries
# --------> Found abs-distortion 10.1363 with 10 queries
# --------> Found comp-distortion 0.6426 with 10 queries
# --------> Found abs-distortion 10.2524 with 10 queries
# --------> Found comp-distortion 0.6436 with 10 queries
# ==========> Found best distortion 10.2524 in 21.5887 seconds
# label before fine binary search: 8
# Iteration  50: g(theta + beta*u) = 3.4528 g(theta) = 3.4515 distortion 3.4515 num_queries 9862
# Iteration 100: g(theta + beta*u) = 2.6157 g(theta) = 2.6156 distortion 2.6156 num_queries 18461
# Iteration 150: g(theta + beta*u) = 2.3501 g(theta) = 2.3500 distortion 2.3500 num_queries 26483
# Iteration 200: g(theta + beta*u) = 2.2106 g(theta) = 2.2107 distortion 2.2107 num_queries 34445
# Iteration 250: g(theta + beta*u) = 2.1385 g(theta) = 2.1385 distortion 2.1385 num_queries 42301
# Iteration 300: g(theta + beta*u) = 2.0915 g(theta) = 2.0915 distortion 2.0915 num_queries 50159
# Iteration 350: g(theta + beta*u) = 2.0671 g(theta) = 2.0673 distortion 2.0673 num_queries 57973
# Iteration 400: g(theta + beta*u) = 2.0488 g(theta) = 2.0489 distortion 2.0489 num_queries 65835
# Warning: not moving, g2 2.044564 gtheta 2.044564
# Iteration 450: g(theta + beta*u) = 2.0391 g(theta) = 2.0391 distortion 2.0391 num_queries 75094
# mnist_baseline
# best distortion : tensor(2.0391)
# number of queries : 85118
# =========================image  15 ==========================================
# true label: 1
# predicted label: 1
# predicted label: 1
# true label: 1
# --------> Found abs-distortion 12.1582 with 10 queries
# --------> Found comp-distortion 0.5659 with 10 queries
# --------> Found abs-distortion 9.4289 with 10 queries
# --------> Found comp-distortion 0.6626 with 10 queries
# --------> Found abs-distortion 8.7808 with 10 queries
# --------> Found comp-distortion 0.6929 with 10 queries
# --------> Found abs-distortion 8.7245 with 10 queries
# --------> Found comp-distortion 0.6934 with 10 queries
# --------> Found abs-distortion 7.6306 with 10 queries
# --------> Found comp-distortion 0.7295 with 10 queries
# --------> Found abs-distortion 8.0701 with 10 queries
# --------> Found comp-distortion 0.7339 with 10 queries
# ==========> Found best distortion 8.0701 in 22.2760 seconds
# label before fine binary search: 8
# Iteration  50: g(theta + beta*u) = 2.7239 g(theta) = 2.7220 distortion 2.7220 num_queries 9898
# Iteration 100: g(theta + beta*u) = 2.0064 g(theta) = 2.0066 distortion 2.0066 num_queries 18198
# Iteration 150: g(theta + beta*u) = 1.8033 g(theta) = 1.8035 distortion 1.8035 num_queries 25701
# Iteration 200: g(theta + beta*u) = 1.7140 g(theta) = 1.7138 distortion 1.7138 num_queries 33363
# Iteration 250: g(theta + beta*u) = 1.6435 g(theta) = 1.6434 distortion 1.6434 num_queries 40904
# Iteration 300: g(theta + beta*u) = 1.6017 g(theta) = 1.6017 distortion 1.6017 num_queries 48357
# Iteration 350: g(theta + beta*u) = 1.5655 g(theta) = 1.5656 distortion 1.5656 num_queries 55681
# Iteration 400: g(theta + beta*u) = 1.5420 g(theta) = 1.5421 distortion 1.5421 num_queries 63031
# Iteration 450: g(theta + beta*u) = 1.5278 g(theta) = 1.5277 distortion 1.5277 num_queries 70372
# Iteration 500: g(theta + beta*u) = 1.5184 g(theta) = 1.5184 distortion 1.5184 num_queries 77740
# mnist_baseline
# best distortion : tensor(1.5184)
# number of queries : 87763
# the average distortion for 15 images : 1.6194718
# 1.7022449
# 2.3781812
# 1.4882486
# 2.2026954
# 1.121366
# 1.4803183
# 0.99946266
# 1.2834355
# 0.99964494
# 1.6415808
# 2.2794616
# 2.1034799
# 1.0544858
# 2.0390816
# 1.5183907
# the number of queries for 15 images : 82505.6
# 82703
# 123652
# 90610
# 98421
# 86828
# 90273
# 39190
# 80967
# 18019
# 92860
# 98029
# 89082
# 74069
# 85118
# 87763
