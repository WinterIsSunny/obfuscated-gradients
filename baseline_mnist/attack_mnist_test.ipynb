# %%
import os 
os.environ["CUDA_VISIBLE_DEVICES"] = "2" 
from keras.datasets import mnist
#import matplotlib
#%matplotlib inline
#import matplotlib.pyplot as plt
#import l2_attack
import keras
#from defense import *
import tensorflow as tf
import time
from torch.autograd import Variable
import torch
import numpy as np
from wrapper import Model
# Out:
# /home/yusu/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
class blackbox:
    def __init__(self,model):
        self.model = model
        
    def attack_untargeted(self, x0, y0, alpha = 4, beta = 0.005, iterations = 1000):
        """ Attack the original image and return adversarial example
            model: (pytorch model)
            alpha: learning rate 
            beta: learning rate
            train_dataset: set of training data
            (x0, y0): original image
        """
        pred = self.model.predict(x0)
        print("predicted label:", pred)
        print("true label:", y0)

#        if (self.model.predict(x0) != y0):
#            print("Fail to classify the image. No need to attack.")
#            return x0
    
        num_directions = 1000
        num_query = 10
        best_theta, g_theta = None, float('inf')
        query_count = 0
        comp_theta = 0
        current_best = float('inf')
        
        timestart = time.time()
        for i in range(num_directions):
            theta = torch.randn(x0.shape).type(torch.FloatTensor)
            initial_lbd = torch.norm(theta)
            theta = theta/torch.norm(theta)
            if self.model.predict(x0+np.array(initial_lbd*theta)) != y0:
                nquery += 1
                lbd,comp_dec = self.fine_grained_binary_search_fix(x0,y0,theta,initial_lbd,g_theta,current_best,num_query)
                if comp_dec > comp_theta:
                    comp_theta = comp_dec
                    best_theta,g_theta = theta,lbd
                    print("--------> Found abs-distortion %.4f with 10 queries" % g_theta)
                    print("--------> Found comp-distortion %.4f with 10 queries" % comp_dec)
            timeend = time.time()
        print("==========> Found best distortion %.4f in %.4f seconds" % (g_theta, timeend-timestart))
        query_count = (num_directions+1)*num_query
        #print("type of best_theta", type(best_theta))
        #print("type of best_theta", type(g_theta))
        lbd,count = self.fine_grained_binary_search( x0, y0, best_theta, g_theta, current_best)
        g_theta = lbd
        query_count += count
        
#        timestart = time.time()
#        for i in range(num_directions):
#            theta = torch.randn(x0.shape).type(torch.FloatTensor)
#            #print(theta.size())
#            initial_lbd = torch.norm(theta)
#            theta = theta/torch.norm(theta)
#            if self.model.predict(x0+np.array(initial_lbd*theta)) != y0:
#                query_count += 1 
#                #print(type(theta),type(initial_lbd),type(g_theta))
#                #print("find a new adv direction, new label:", self.model.predict(x0+np.array(initial_lbd*theta)))
#                lbd, count = self.fine_grained_binary_search( x0, y0, theta, initial_lbd, g_theta)
#                query_count += count
#                if lbd < g_theta:
#                    best_theta, g_theta = theta,lbd
##                    print("label for random direction:",self.model.predict(x0+np.array(g_theta*best_theta)))
#                    print("--------> Found distortion %.4f" % g_theta)
#        
#            timeend = time.time()
#            print("==========> Found best distortion %.4f in %.4f seconds using %d queries" % (g_theta, timeend-timestart, query_count))
        
        
        
        
    
        g1 = 1.0
        theta, g2 = best_theta.clone(), g_theta
        torch.manual_seed(0)
        opt_count = 0
        stopping = 0.01
        prev_obj = 100000
        for i in range(iterations):
 
            if g_theta < 1:
                print("====================query number after distortion < 1 =======================: ",opt_count)
                break
            gradient = torch.zeros(theta.size())
            q = 10
            min_g1 = float('inf')
            for j in range(q):
                u = torch.randn(theta.size()).type(torch.FloatTensor)
                u = u/torch.norm(u)
                ttt = theta+beta * u
                ttt = ttt/torch.norm(ttt)
                #print("inner loop iteration: ", j)
                g1, count = self.fine_grained_binary_search_local( x0, y0, ttt, initial_lbd = g2, tol=beta/500)
                opt_count += count
                gradient += (g1-g2)/beta * u
                if g1 < min_g1:
                    min_g1 = g1
                    min_ttt = ttt
            gradient = 1.0/q * gradient
#            print("=============================================")
    
            if (i+1)%50 == 0:
                
                print("Iteration %3d: g(theta + beta*u) = %.4f g(theta) = %.4f distortion %.4f num_queries %d" % (i+1, g1, g2, torch.norm(g2*theta), opt_count))
                if g2 > prev_obj-stopping:
                    break
                prev_obj = g2
    
            min_theta = theta
            min_g2 = g2
            

            for _ in range(15):
                new_theta = theta - alpha * gradient
                new_theta = new_theta/torch.norm(new_theta)
                new_g2, count = self.fine_grained_binary_search_local( x0, y0, new_theta, initial_lbd = min_g2, tol=beta/50)
                opt_count += count
                alpha = alpha * 2
#                print("alpha in the first for loop is: ",alpha)
                if new_g2 < min_g2:
                    min_theta = new_theta 
                    min_g2 = new_g2
                else:
                    break
#            print("=============================================")
    
            if min_g2 >= g2:
                for _ in range(15):
                    alpha = alpha * 0.5
                    new_theta = theta - alpha * gradient
                    new_theta = new_theta/torch.norm(new_theta)
                    new_g2, count = self.fine_grained_binary_search_local( x0, y0, new_theta, initial_lbd = min_g2, tol=beta/50)
                    opt_count += count
#                    print("alpha in the second for loop is: ",alpha)
                    if new_g2 < g2:
                        min_theta = new_theta 
                        min_g2 = new_g2
                        break
#            print("=============================================")
            if min_g2 <= min_g1:
                theta, g2 = min_theta, min_g2
            else:
                theta, g2 = min_ttt, min_g1
    
            if g2 < g_theta:
                best_theta, g_theta = theta.clone(), g2
            
            #print(alpha)
#            print("%3d th iteration" % i)
#            print("current alpha:",alpha)
#            print("g_theta")
#            print("number of queries:", opt_count+query_count)
            if alpha < 1e-4:
                alpha = 1.0
                print("Warning: not moving, g2 %lf gtheta %lf" % (g2, g_theta))
                beta = beta * 0.1
                if (beta < 1e-5):
                    print("beta is too samll")
                    break

    
        #target = model.predict(x0 + g_theta*best_theta)
        
        #print("\nAdversarial Example Found Successfully: distortion %.4f target %d queries %d \nTime: %.4f seconds" % (g_theta, target, query_count + opt_count, timeend-timestart))
        print("mnist_baseline")
        print("best distortion :", g_theta)
        print("number of queries :", opt_count+query_count)
        return x0 + np.array(g_theta*best_theta), opt_count+query_count
    def fine_grained_binary_search_local(self, x0, y0, theta, initial_lbd = 1.0, tol=1e-5):
        nquery = 0
        lbd = initial_lbd
        
        if self.model.predict(x0+np.array(lbd*theta)) == y0:
            lbd_lo = lbd
            lbd_hi = lbd*1.01
            nquery += 1
            #timestart1 = time.time()
            while self.model.predict(x0+np.array(lbd_hi*theta)) == y0:
                lbd_hi = lbd_hi*1.01
                nquery += 1
                if lbd_hi > 20:
                    return float('inf'), nquery
            #timeend1 = time.time()
#            print("1st while time:", timeend1 - timestart1)
        else:
            lbd_hi = lbd
            lbd_lo = lbd*0.99
            nquery += 1
            #timestart2 = time.time()
            while self.model.predict(x0+ np.array(lbd_lo*theta)) != y0 :
                lbd_lo = lbd_lo*0.99
                nquery += 1
            #timeend2 = time.time()
#            print("2nd while time:", timeend2 - timestart2)
            
        #timestart3 = time.time()
        while (lbd_hi - lbd_lo) > tol:
            lbd_mid = (lbd_lo + lbd_hi)/2.0
            nquery += 1
            if self.model.predict(x0 + np.array(lbd_mid*theta)) != y0:
                lbd_hi = lbd_mid
            else:
                lbd_lo = lbd_mid
        #timeend3 = time.time()
#        print("3rd while time:",timeend3 - timestart3)
#        print("lbd_low:",lbd_lo)
#        print("lbd_high:", lbd_hi)
#        print("-----------------------------")
        return lbd_hi, nquery
    
    def fine_grained_binary_search_fix(self,x0,y0,theta, initial_lbd = 1.0, tol=1e-5,current_best = float('inf'),num_query = 10):
        nquery = 0
        if initial_lbd > current_best: 
            if self.model.predict(x0+ np.array(current_best*theta)) == y0:
                nquery += 1
                return float('inf'), nquery
            lbd = current_best
        else:
            lbd = initial_lbd
    
        lbd_hi = lbd
        lbd_lo = 0.0
    
        while (lbd_hi - lbd_lo) > 1e-5:
            lbd_mid = (lbd_lo + lbd_hi)/2.0
            nquery += 1
            if self.model.predict(x0 + np.array(lbd_mid*theta)) != y0:
                lbd_hi = lbd_mid
            else:
                lbd_lo = lbd_mid
            if nquery > num_query:
                break
        comp_dec = (initial_lbd - lbd_hi)/initial_lbd
       # print("number of query before return for this direction:",nquery)
        return lbd_hi,comp_dec,
    
    def fine_grained_binary_search(self, x0, y0, theta, initial_lbd, current_best):
        nquery = 0
        if initial_lbd > current_best: 
            if self.model.predict(x0+ np.array(current_best*theta)) == y0:
                nquery += 1
                #print("initial_lbd > current_best & predict == y0, so return inf")
                return float('inf'), nquery
            lbd = current_best
        else:
            lbd = initial_lbd
            
        ## original version
        #lbd = initial_lbd
        #while model.predict(x0 + lbd*theta) == y0:
        #    lbd *= 2
        #    nquery += 1
        #    if lbd > 100:
        #        return float('inf'), nquery
        
        #num_intervals = 100
    
        # lambdas = np.linspace(0.0, lbd, num_intervals)[1:]
        # lbd_hi = lbd
        # lbd_hi_index = 0
        # for i, lbd in enumerate(lambdas):
        #     nquery += 1
        #     if model.predict(x0 + lbd*theta) != y0:
        #         lbd_hi = lbd
        #         lbd_hi_index = i
        #         break
    
        # lbd_lo = lambdas[lbd_hi_index - 1]
        lbd_hi = lbd
        lbd_lo = 0.
        print("label before fine binary search:", self.model.predict(x0+ np.array(lbd_hi*theta)))
    
        while (lbd_hi - lbd_lo) > 1e-3:
            lbd_mid = (lbd_lo + lbd_hi)/2.0
            nquery += 1
            if self.model.predict(x0 + np.array(lbd_mid*theta)) != y0:
                lbd_hi = lbd_mid
            else:
                lbd_lo = lbd_mid
        #print("find a better initialization")
        return lbd_hi, nquery

# %%
session = keras.backend.get_session()
keras.backend.set_learning_phase(False)
model = keras.models.load_model("data/mnist")
model = Model(model,[0.0,1.0])

attack = blackbox(model)

#touse = [x for x in tf.trainable_variables() if 'Generator' in x.name]
#saver = tf.train.Saver(touse)
#saver.restore(session, 'data/mnist-gan')

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_test = np.array(x_test, dtype=np.float32)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
x_test /= 255.0
#image = x_test[:1]
#adv = attack.attack_untargeted(image[0],y_test[0], alpha = 4, beta = 0.005, iterations = 1000)
count = []
for i in range(20):
    label = model.predict(x_test[i])
    if label == y_test[i]:
        count.append(1)
    else:
        count.append(0)
    
print("accuracy of this model is:", sum(count)/len(count))
# Out:
# accuracy of this model is: 0.95

# %%
dist = []
count = []
for i in range(15):
    print("=========================image ",i+1,"==========================================")
    print("true label:",y_test[i+20])
    print("predicted label:",model.predict(x_test[i+20]))
    adv, queries= attack.attack_untargeted(x_test[i+20],y_test[i+20], alpha = 4, beta = 0.005, iterations = 1000)
    res = adv - x_test[i+20]
    dist.append(np.linalg.norm(res))
    count.append(queries)

index = np.nonzero(count)
index = list(index)[0].tolist()

avg_distortion = np.mean(np.array(dist)[index])
avg_count = np.mean(np.array(count)[index])
print("the average distortion for %2d images :"%(len(index)),avg_distortion)
for i in dist:
    print(i)
print("the number of queries for %2d images :"%(len(index)), avg_count)
for j in count:
    print(j)
# Out:
# =========================image  1 ==========================================
# true label: 9
# predicted label: 9
# predicted label: 9
# true label: 9
# --------> Found abs-distortion 19.4409 with 10 queries
# --------> Found comp-distortion 0.2832 with 10 queries
# --------> Found abs-distortion 10.0882 with 10 queries
# --------> Found comp-distortion 0.6421 with 10 queries
# --------> Found abs-distortion 10.0992 with 10 queries
# --------> Found comp-distortion 0.6562 with 10 queries
# --------> Found abs-distortion 8.5141 with 10 queries
# --------> Found comp-distortion 0.7090 with 10 queries
# --------> Found abs-distortion 7.7385 with 10 queries
# --------> Found comp-distortion 0.7163 with 10 queries
# --------> Found abs-distortion 7.6960 with 10 queries
# --------> Found comp-distortion 0.7241 with 10 queries
# --------> Found abs-distortion 7.4088 with 10 queries
# --------> Found comp-distortion 0.7476 with 10 queries
# ==========> Found best distortion 7.4088 in 21.8578 seconds
# label before fine binary search: 8
# Iteration  50: g(theta + beta*u) = 1.8372 g(theta) = 1.8384 distortion 1.8384 num_queries 9755
# Iteration 100: g(theta + beta*u) = 1.1988 g(theta) = 1.1989 distortion 1.1989 num_queries 18187
# Iteration 150: g(theta + beta*u) = 1.0188 g(theta) = 1.0188 distortion 1.0188 num_queries 25574
# ====================query number after distortion < 1 =======================:  26839
# mnist_baseline
# best distortion : tensor(0.9992)
# number of queries : 36862
# =========================image  2 ==========================================
# true label: 6
# predicted label: 6
# predicted label: 6
# true label: 6
# --------> Found abs-distortion 12.4157 with 10 queries
# --------> Found comp-distortion 0.5498 with 10 queries
# --------> Found abs-distortion 11.6294 with 10 queries
# --------> Found comp-distortion 0.5854 with 10 queries
# --------> Found abs-distortion 11.1879 with 10 queries
# --------> Found comp-distortion 0.6011 with 10 queries
# --------> Found abs-distortion 11.2142 with 10 queries
# --------> Found comp-distortion 0.6123 with 10 queries
# --------> Found abs-distortion 9.1931 with 10 queries
# --------> Found comp-distortion 0.6763 with 10 queries
# --------> Found abs-distortion 9.0811 with 10 queries
# --------> Found comp-distortion 0.6831 with 10 queries
# --------> Found abs-distortion 8.6835 with 10 queries
# --------> Found comp-distortion 0.6982 with 10 queries
# ==========> Found best distortion 8.6835 in 20.8885 seconds
# label before fine binary search: 5
# Iteration  50: g(theta + beta*u) = 2.0153 g(theta) = 2.0156 distortion 2.0156 num_queries 9656
# Iteration 100: g(theta + beta*u) = 1.6332 g(theta) = 1.6331 distortion 1.6331 num_queries 18313
# Iteration 150: g(theta + beta*u) = 1.4097 g(theta) = 1.4096 distortion 1.4096 num_queries 26322
# Iteration 200: g(theta + beta*u) = 1.2878 g(theta) = 1.2878 distortion 1.2878 num_queries 33965
# Iteration 250: g(theta + beta*u) = 1.2197 g(theta) = 1.2198 distortion 1.2198 num_queries 41285
# Iteration 300: g(theta + beta*u) = 1.1875 g(theta) = 1.1876 distortion 1.1876 num_queries 48555
# Iteration 350: g(theta + beta*u) = 1.1662 g(theta) = 1.1662 distortion 1.1662 num_queries 55785
# Iteration 400: g(theta + beta*u) = 1.1542 g(theta) = 1.1541 distortion 1.1541 num_queries 62965
# Warning: not moving, g2 1.150588 gtheta 1.150588
# Iteration 450: g(theta + beta*u) = 1.1457 g(theta) = 1.1456 distortion 1.1456 num_queries 71745
# mnist_baseline
# best distortion : tensor(1.1456)
# number of queries : 81769
# =========================image  3 ==========================================
# true label: 6
# predicted label: 6
# predicted label: 6
# true label: 6
# --------> Found abs-distortion 17.4646 with 10 queries
# --------> Found comp-distortion 0.3765 with 10 queries
# --------> Found abs-distortion 13.4588 with 10 queries
# --------> Found comp-distortion 0.5156 with 10 queries
# --------> Found abs-distortion 12.9192 with 10 queries
# --------> Found comp-distortion 0.5400 with 10 queries
# --------> Found abs-distortion 12.1143 with 10 queries
# --------> Found comp-distortion 0.5742 with 10 queries
# --------> Found abs-distortion 11.3427 with 10 queries
# --------> Found comp-distortion 0.5967 with 10 queries
# --------> Found abs-distortion 10.0142 with 10 queries
# --------> Found comp-distortion 0.6543 with 10 queries
# ==========> Found best distortion 10.0142 in 19.2939 seconds
# label before fine binary search: 8
# Iteration  50: g(theta + beta*u) = 3.2153 g(theta) = 3.2144 distortion 3.2144 num_queries 9965
# Iteration 100: g(theta + beta*u) = 2.4058 g(theta) = 2.4052 distortion 2.4052 num_queries 18453
# Iteration 150: g(theta + beta*u) = 2.1488 g(theta) = 2.1493 distortion 2.1493 num_queries 26523
# Iteration 200: g(theta + beta*u) = 2.0477 g(theta) = 2.0476 distortion 2.0476 num_queries 34404
# Iteration 250: g(theta + beta*u) = 1.9971 g(theta) = 1.9971 distortion 1.9971 num_queries 41939
# Iteration 300: g(theta + beta*u) = 1.9609 g(theta) = 1.9607 distortion 1.9607 num_queries 49235
# Warning: not moving, g2 1.937787 gtheta 1.937787
# Iteration 350: g(theta + beta*u) = 1.9364 g(theta) = 1.9364 distortion 1.9364 num_queries 57076
# Iteration 400: g(theta + beta*u) = 1.9251 g(theta) = 1.9251 distortion 1.9251 num_queries 67012
# Iteration 450: g(theta + beta*u) = 1.9177 g(theta) = 1.9177 distortion 1.9177 num_queries 76932
# mnist_baseline
# best distortion : tensor(1.9177)
# number of queries : 86956
# =========================image  4 ==========================================
# true label: 5
# predicted label: 5
# predicted label: 5
# true label: 5
# --------> Found abs-distortion 25.0452 with 10 queries
# --------> Found comp-distortion 0.0986 with 10 queries
# --------> Found abs-distortion 17.1930 with 10 queries
# --------> Found comp-distortion 0.3848 with 10 queries
# --------> Found abs-distortion 10.6665 with 10 queries
# --------> Found comp-distortion 0.6152 with 10 queries
# ==========> Found best distortion 10.6665 in 16.5737 seconds
# label before fine binary search: 8
# Iteration  50: g(theta + beta*u) = 3.5526 g(theta) = 3.5525 distortion 3.5525 num_queries 9591
# Iteration 100: g(theta + beta*u) = 2.7015 g(theta) = 2.7018 distortion 2.7018 num_queries 18400
# Iteration 150: g(theta + beta*u) = 2.3785 g(theta) = 2.3783 distortion 2.3783 num_queries 26594
# Iteration 200: g(theta + beta*u) = 2.2077 g(theta) = 2.2077 distortion 2.2077 num_queries 34560
# Iteration 250: g(theta + beta*u) = 2.1197 g(theta) = 2.1198 distortion 2.1198 num_queries 42428
# Iteration 300: g(theta + beta*u) = 2.0627 g(theta) = 2.0627 distortion 2.0627 num_queries 50294
# Iteration 350: g(theta + beta*u) = 2.0320 g(theta) = 2.0320 distortion 2.0320 num_queries 58046
# Iteration 400: g(theta + beta*u) = 2.0119 g(theta) = 2.0119 distortion 2.0119 num_queries 65584
# Warning: not moving, g2 1.996265 gtheta 1.996265
# Iteration 450: g(theta + beta*u) = 1.9953 g(theta) = 1.9953 distortion 1.9953 num_queries 73369
# Iteration 500: g(theta + beta*u) = 1.9864 g(theta) = 1.9864 distortion 1.9864 num_queries 83265
# mnist_baseline
# best distortion : tensor(1.9864)
# number of queries : 93289
# =========================image  5 ==========================================
# true label: 4
# predicted label: 4
# predicted label: 4
# true label: 4
# --------> Found abs-distortion 12.5310 with 10 queries
# --------> Found comp-distortion 0.5498 with 10 queries
# --------> Found abs-distortion 11.2123 with 10 queries
# --------> Found comp-distortion 0.6001 with 10 queries
# --------> Found abs-distortion 9.8505 with 10 queries
# --------> Found comp-distortion 0.6470 with 10 queries
# --------> Found abs-distortion 9.5426 with 10 queries
# --------> Found comp-distortion 0.6646 with 10 queries
# --------> Found abs-distortion 8.0543 with 10 queries
# --------> Found comp-distortion 0.7109 with 10 queries
# ==========> Found best distortion 8.0543 in 20.5663 seconds
# label before fine binary search: 9
# Iteration  50: g(theta + beta*u) = 2.1617 g(theta) = 2.1615 distortion 2.1615 num_queries 9352
# Iteration 100: g(theta + beta*u) = 1.6944 g(theta) = 1.6945 distortion 1.6945 num_queries 17829
# Iteration 150: g(theta + beta*u) = 1.4898 g(theta) = 1.4899 distortion 1.4899 num_queries 25749
# Iteration 200: g(theta + beta*u) = 1.3720 g(theta) = 1.3719 distortion 1.3719 num_queries 33462
# Iteration 250: g(theta + beta*u) = 1.2756 g(theta) = 1.2756 distortion 1.2756 num_queries 41033
# Iteration 300: g(theta + beta*u) = 1.2243 g(theta) = 1.2242 distortion 1.2242 num_queries 48333
# Iteration 350: g(theta + beta*u) = 1.1913 g(theta) = 1.1914 distortion 1.1914 num_queries 55633
# Iteration 400: g(theta + beta*u) = 1.1679 g(theta) = 1.1678 distortion 1.1678 num_queries 62923
# Iteration 450: g(theta + beta*u) = 1.1512 g(theta) = 1.1512 distortion 1.1512 num_queries 70123
# Warning: not moving, g2 1.145586 gtheta 1.145586
# Iteration 500: g(theta + beta*u) = 1.1399 g(theta) = 1.1399 distortion 1.1399 num_queries 78709
# Iteration 550: g(theta + beta*u) = 1.1308 g(theta) = 1.1308 distortion 1.1308 num_queries 88037
# mnist_baseline
# best distortion : tensor(1.1308)
# number of queries : 98060
# =========================image  6 ==========================================
# true label: 0
# predicted label: 0
# predicted label: 0
# true label: 0
# --------> Found abs-distortion 22.2526 with 10 queries
# --------> Found comp-distortion 0.1978 with 10 queries
# --------> Found abs-distortion 19.8418 with 10 queries
# --------> Found comp-distortion 0.2920 with 10 queries
# --------> Found abs-distortion 14.0982 with 10 queries
# --------> Found comp-distortion 0.4800 with 10 queries
# --------> Found abs-distortion 13.7103 with 10 queries
# --------> Found comp-distortion 0.4946 with 10 queries
# --------> Found abs-distortion 12.5977 with 10 queries
# --------> Found comp-distortion 0.5630 with 10 queries
# --------> Found abs-distortion 11.5771 with 10 queries
# --------> Found comp-distortion 0.5796 with 10 queries
# --------> Found abs-distortion 10.8384 with 10 queries
# --------> Found comp-distortion 0.6167 with 10 queries
# ==========> Found best distortion 10.8384 in 19.5935 seconds
# label before fine binary search: 8
# Iteration  50: g(theta + beta*u) = 3.2603 g(theta) = 3.2601 distortion 3.2601 num_queries 9524
# Iteration 100: g(theta + beta*u) = 2.5346 g(theta) = 2.5344 distortion 2.5344 num_queries 18099
# Iteration 150: g(theta + beta*u) = 2.2471 g(theta) = 2.2473 distortion 2.2473 num_queries 26157
# Iteration 200: g(theta + beta*u) = 2.1297 g(theta) = 2.1293 distortion 2.1293 num_queries 34061
# Iteration 250: g(theta + beta*u) = 2.0610 g(theta) = 2.0609 distortion 2.0609 num_queries 41947
# Iteration 300: g(theta + beta*u) = 2.0257 g(theta) = 2.0255 distortion 2.0255 num_queries 49676
# Iteration 350: g(theta + beta*u) = 2.0041 g(theta) = 2.0040 distortion 2.0040 num_queries 57176
# Warning: not moving, g2 1.996549 gtheta 1.996549
# Iteration 400: g(theta + beta*u) = 1.9928 g(theta) = 1.9928 distortion 1.9928 num_queries 65919
# Iteration 450: g(theta + beta*u) = 1.9841 g(theta) = 1.9841 distortion 1.9841 num_queries 75839
# mnist_baseline
# best distortion : tensor(1.9841)
# number of queries : 85863
# =========================image  7 ==========================================
# true label: 7
# predicted label: 7
# predicted label: 7
# true label: 7
# --------> Found abs-distortion 14.1823 with 10 queries
# --------> Found comp-distortion 0.4937 with 10 queries
# --------> Found abs-distortion 13.2548 with 10 queries
# --------> Found comp-distortion 0.5117 with 10 queries
# --------> Found abs-distortion 12.5828 with 10 queries
# --------> Found comp-distortion 0.5327 with 10 queries
# --------> Found abs-distortion 12.0503 with 10 queries
# --------> Found comp-distortion 0.5752 with 10 queries
# --------> Found abs-distortion 11.3089 with 10 queries
# --------> Found comp-distortion 0.5918 with 10 queries
# --------> Found abs-distortion 10.8754 with 10 queries
# --------> Found comp-distortion 0.6147 with 10 queries
# --------> Found abs-distortion 10.2845 with 10 queries
# --------> Found comp-distortion 0.6426 with 10 queries
# --------> Found abs-distortion 10.1238 with 10 queries
# --------> Found comp-distortion 0.6431 with 10 queries
# --------> Found abs-distortion 9.3104 with 10 queries
# --------> Found comp-distortion 0.6606 with 10 queries
# ==========> Found best distortion 9.3104 in 19.9834 seconds
# label before fine binary search: 3
# Iteration  50: g(theta + beta*u) = 2.8206 g(theta) = 2.8214 distortion 2.8214 num_queries 9412
# Iteration 100: g(theta + beta*u) = 2.2529 g(theta) = 2.2525 distortion 2.2525 num_queries 17924
# Iteration 150: g(theta + beta*u) = 2.0031 g(theta) = 2.0029 distortion 2.0029 num_queries 25950
# Iteration 200: g(theta + beta*u) = 1.8861 g(theta) = 1.8862 distortion 1.8862 num_queries 33438
# Iteration 250: g(theta + beta*u) = 1.8211 g(theta) = 1.8212 distortion 1.8212 num_queries 40842
# Iteration 300: g(theta + beta*u) = 1.7756 g(theta) = 1.7756 distortion 1.7756 num_queries 48231
# Iteration 350: g(theta + beta*u) = 1.7509 g(theta) = 1.7507 distortion 1.7507 num_queries 55596
# Iteration 400: g(theta + beta*u) = 1.7366 g(theta) = 1.7365 distortion 1.7365 num_queries 62910
# Warning: not moving, g2 1.732027 gtheta 1.732027
# Iteration 450: g(theta + beta*u) = 1.7262 g(theta) = 1.7262 distortion 1.7262 num_queries 71925
# Iteration 500: g(theta + beta*u) = 1.7164 g(theta) = 1.7164 distortion 1.7164 num_queries 81703
# mnist_baseline
# best distortion : tensor(1.7164)
# number of queries : 91727
# =========================image  8 ==========================================
# true label: 4
# predicted label: 4
# predicted label: 4
# true label: 4
# --------> Found abs-distortion 17.5461 with 10 queries
# --------> Found comp-distortion 0.3696 with 10 queries
# --------> Found abs-distortion 16.9417 with 10 queries
# --------> Found comp-distortion 0.4102 with 10 queries
# --------> Found abs-distortion 15.6178 with 10 queries
# --------> Found comp-distortion 0.4331 with 10 queries
# --------> Found abs-distortion 13.2430 with 10 queries
# --------> Found comp-distortion 0.5254 with 10 queries
# --------> Found abs-distortion 12.0335 with 10 queries
# --------> Found comp-distortion 0.5762 with 10 queries
# --------> Found abs-distortion 12.2439 with 10 queries
# --------> Found comp-distortion 0.5767 with 10 queries
# --------> Found abs-distortion 11.4129 with 10 queries
# --------> Found comp-distortion 0.6001 with 10 queries
# --------> Found abs-distortion 10.8538 with 10 queries
# --------> Found comp-distortion 0.6060 with 10 queries
# ==========> Found best distortion 10.8538 in 21.0762 seconds
# label before fine binary search: 8
# Iteration  50: g(theta + beta*u) = 3.0431 g(theta) = 3.0435 distortion 3.0435 num_queries 10055
# Iteration 100: g(theta + beta*u) = 2.2762 g(theta) = 2.2761 distortion 2.2761 num_queries 18605
# Iteration 150: g(theta + beta*u) = 1.9906 g(theta) = 1.9907 distortion 1.9907 num_queries 26573
# Iteration 200: g(theta + beta*u) = 1.8596 g(theta) = 1.8593 distortion 1.8593 num_queries 34019
# Iteration 250: g(theta + beta*u) = 1.7914 g(theta) = 1.7916 distortion 1.7916 num_queries 41445
# Iteration 300: g(theta + beta*u) = 1.7498 g(theta) = 1.7499 distortion 1.7499 num_queries 48770
# Iteration 350: g(theta + beta*u) = 1.7175 g(theta) = 1.7176 distortion 1.7176 num_queries 56118
# Warning: not moving, g2 1.706778 gtheta 1.706778
# Iteration 400: g(theta + beta*u) = 1.7017 g(theta) = 1.7017 distortion 1.7017 num_queries 64806
# Iteration 450: g(theta + beta*u) = 1.6911 g(theta) = 1.6911 distortion 1.6911 num_queries 74624
# Warning: not moving, g2 1.689988 gtheta 1.689988
