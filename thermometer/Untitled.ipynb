# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "4"

import tensorflow as tf
import numpy as np
import math
import matplotlib.pyplot as plt
#%matplotlib inline

import cifar10_input

from discretization_utils import one_hot_to_thermometer
from discretization_utils import discretize_uniform
from discretization_attacks import adv_lspga

from cifar_model import Model
import cifar10_input

import torch
from wrapper import MyModel
import time
torch.set_printoptions(precision=20)

# %%
class blackbox:
    def __init__(self,model):
        self.model = model
        
    def attack_untargeted(self, x0, y0, alpha = 0.2, beta = 0.05, iterations = 1000):
        """ Attack the original image and return adversarial example
            model: (pytorch model)
            alpha: learning rate 
            beta: learning rate
            train_dataset: set of training data
            (x0, y0): original image
        """
        if self.model.predict(x0) != y0:
            print("Fail to classify the image. No need to attack.")
            return x0,0
    
        num_directions = 100
        best_theta, g_theta = None, float('inf')
        query_count = 0
        
        timestart = time.time()
        
        
        for i in range(num_directions):
            theta = torch.randn(x0.shape).type(torch.FloatTensor)
            initial_lbd = torch.norm(theta)
            theta = theta/torch.norm(theta)
            pred = self.model.predict(x0+np.array(initial_lbd*theta))
            if pred != y0:
                #print("new feasible initialization:", pred)
                query_count += 1
                lbd, count = self.fine_grained_binary_search( x0, y0, theta, initial_lbd, g_theta)
                query_count += count
                if lbd < g_theta:
                    best_theta, g_theta = theta,lbd
                    print("--------> Found distortion %.4f in iterationn %d" % (g_theta,i))
        timeend = time.time()
        print("==========> Found best distortion %.4f in %.4f seconds using %d queries" % (g_theta, timeend-timestart, query_count))
        
        
        g1 = 1.0
        theta, g2 = best_theta.clone(), g_theta
        torch.manual_seed(0)
        opt_count = 0
        stopping = 0.01
        prev_obj = 100000
        for i in range(iterations):
            print("iteration %d , distortion %.4f "% (i+1,g_theta))
            timestart = time.time()
            if g_theta < 2:
                print("============query number after distortion < 2 ==============:",opt_count+query_count)
                break
            
            gradient = torch.zeros(theta.size())
            #print("type of gradiennt", type(gradient))
            q = 10
            min_g1 = float('inf')
            for _ in range(q):
                u = torch.randn(theta.size()).type(torch.FloatTensor)
                u = u/torch.norm(u)
                #print("type of u", type(u))
                ttt = theta+beta * u
                ttt = ttt/torch.norm(ttt)
                g1, count = self.fine_grained_binary_search_local( x0, y0, ttt, initial_lbd = g2, tol=beta/500)
                opt_count += count
                #print("type of g1", type(g1))
                #print("type of g2", type(g2))
                
                gradient +=  (g1-g2)/beta * u
                #print("norm of gradient:", np.linalg.norm(gradient))
                if g1 < min_g1:
                    min_g1 = g1
                    min_ttt = ttt
            gradient = 1.0/q * gradient
    
            if (i+1)%50 == 0:
                print("Iteration %3d: g(theta + beta*u) = %.4f g(theta) = %.4f distortion %.4f num_queries %d" % (i+1, g1, g2, torch.norm(g2*theta), opt_count))
                if g2 > prev_obj-stopping:
                    break
                prev_obj = g2
    
            min_theta = theta
            min_g2 = g2
        
            for _ in range(5):
                #print("enter first for loop")
                new_theta = theta - alpha * gradient
                new_theta = new_theta/torch.norm(new_theta)
                new_g2, count = self.fine_grained_binary_search_local( x0, y0, new_theta, initial_lbd = min_g2, tol=beta/500)
                opt_count += count
                alpha = alpha * 2
                #print("alpha in the first for loop is: ",alpha)
                if new_g2 < min_g2:
                    min_theta = new_theta 
                    min_g2 = new_g2
                else:
                    break
            #print("alpha after first for loop :", alpha)
    
            if min_g2 >= g2:
                for _ in range(15):
                    #print("enter second for loop")
                    alpha = alpha * 0.25
                    new_theta = theta - alpha * gradient
                    new_theta = new_theta/torch.norm(new_theta)
                    new_g2, count = self.fine_grained_binary_search_local( x0, y0, new_theta, initial_lbd = min_g2, tol=beta/500)
                    opt_count += count
                    #print("alpha in the second for loop is: ",alpha)
                    if new_g2 < g2:
                        min_theta = new_theta 
                        min_g2 = new_g2
                        break
                #print("alpha after second for loop :", alpha)
    
            if min_g2 <= min_g1:
                theta, g2 = min_theta, min_g2
            else:
                theta, g2 = min_ttt, min_g1
    
            if g2 < g_theta:
                best_theta, g_theta = theta.clone(), g2
            
            #print(alpha)
#            print("%3d th iteration" % i)
            #print("current alpha:",alpha)
            if alpha < 1e-4:
                alpha = 1.0
                #print("Warning: not moving, g2 %lf gtheta %lf" % (g2, g_theta))
                beta = beta * 0.1
                if (beta < 1e-5):
                    break
            #print("time consuming in this iteration:",timeend - timestart)
            #print("iteration:",i)
            #print("query so far:", query_count+opt_count)
    
        #target = model.predict(x0 + g_theta*best_theta)
        #print("\nAdversarial Example Found Successfully: distortion %.4f target %d queries %d \nTime: %.4f seconds" % (g_theta, target, query_count + opt_count, timeend-timestart))
        print("thermometer")
        print("best distortion :", g_theta)
        print("number of queries :", opt_count+query_count)
        return np.array(g_theta*best_theta), opt_count+query_count
    def fine_grained_binary_search_fix(self,x0,y0,theta, initial_lbd = 1.0, tol=1e-5,current_best = float('inf'),num_query = 10):
        nquery = 0
        if initial_lbd > current_best: 
            if self.model.predict(x0+ np.array(current_best*theta)) == y0:
                nquery += 1
                return float('inf'), nquery
            lbd = current_best
        else:
            lbd = initial_lbd
    
        lbd_hi = lbd
        lbd_lo = 0.0
    
        while not np.isclose(lbd_hi,lbd_lo,tol):
            lbd_mid = (lbd_lo + lbd_hi)/2.0
            nquery += 1
            if self.model.predict(x0 + np.array(lbd_mid*theta)) != y0:
                lbd_hi = lbd_mid
            else:
                lbd_lo = lbd_mid
            if nquery > num_query:
                break
        comp_dec = (initial_lbd - lbd_hi)/initial_lbd
       # print("number of query before return for this direction:",nquery)
        return lbd_hi,comp_dec,nquery
    
    def fine_grained_binary_search_local(self, x0, y0, theta, initial_lbd = 1.0, tol=1e-5):
        nquery = 0
        lbd = initial_lbd
        #print("type of lbd before", type(lbd))
        lbd = np.array(lbd)
        #print("type of lbd after", type(lbd))
        
        if self.model.predict(x0+np.array(lbd*theta)) == y0:
            lbd_lo = lbd*1
            lbd_hi = lbd*1.01
            nquery += 1
            while self.model.predict(x0+np.array(lbd_hi*theta)) == y0:
                lbd_hi = lbd_hi*1.01
                nquery += 1
                if lbd_hi > 100:
                    return float('inf'), nquery
        else:
            lbd_hi = lbd*1
            lbd_lo = lbd*0.99
            nquery += 1
            while self.model.predict(x0+np.array(lbd_lo*theta)) != y0 :
                lbd_lo = lbd_lo*0.99
                nquery += 1
    
        #print("type of lbd_hi before while",type(lbd_hi))
       # print("type of lbd_lo before while",type(lbd_lo))
       # print("type of tol before while",type(tol))
        
        while (lbd_hi - lbd_lo) > tol:
            lbd_mid = (lbd_lo + lbd_hi)/2.0
            nquery += 1
            if self.model.predict(x0 + np.array(lbd_mid*theta)) != y0:
                lbd_hi = lbd_mid
            else:
                lbd_lo = lbd_mid
            #print("while loop in local binary",lbd_hi,lbd_lo,lbd_mid,lbd_hi - lbd_lo,tol)
        lbd_hi = np.array(lbd_hi)
        lbd_hi = torch.FloatTensor(lbd_hi)
        #print("size of lbd_hi",lbd_hi.size())
        #print("type of lbd_hi ", type(lbd_hi))

        return lbd_hi, nquery
    
    def fine_grained_binary_search(self, x0, y0, theta, initial_lbd, current_best):
        nquery = 0
        if initial_lbd > current_best: 
            if self.model.predict(x0+ np.array(current_best*theta)) == y0:
                nquery += 1
                return float('inf'), nquery
            lbd = current_best
        else:
            lbd = initial_lbd
        
        lbd_hi = lbd
        lbd_lo = 0.0
    
        while (lbd_hi - lbd_lo) > 1e-5:
            lbd_mid = (lbd_lo + lbd_hi)/2.0
            nquery += 1
            if self.model.predict(x0 + np.array(lbd_mid*theta)) != y0:
                lbd_hi = lbd_mid
            else:
                lbd_lo = lbd_mid
        return lbd_hi, nquery

# %%
levels = 16

sess = tf.Session(config=tf.ConfigProto(log_device_placement=False))
cifar = cifar10_input.CIFAR10Data()
model = Model('../models/thermometer_advtrain/',
              sess, tiny=False, mode='eval',
              thermometer=True, levels=levels)
model = MyModel(model,sess,levels,[0.0,255.0])

image = np.array(cifar.eval_data.xs[:100],dtype=np.float32)
labels = cifar.eval_data.ys[:100]

new_img = image / 255.0
print("type of image:", type(new_img))
count = []
for i in range(20):
    label = model.predict(new_img[i])
    if label == labels[i]:
        count.append(1)
    else:
        count.append(0)
    
print("accuracy of this model is:", sum(count)/len(count))

attack = blackbox(model)
# Out:
# Called
# INFO:tensorflow:Restoring parameters from ../models/thermometer_advtrain/checkpoint-68000
# restored
# type of image: <class 'numpy.ndarray'>
# accuracy of this model is: 0.95

# %%
timestart = time.time()
label = model.predict(new_img[0])
timeend = time.time()
print("it costs %.4f seconds to query once, the label is %3d "%(timeend-timestart, label))
# Out:
# it costs 0.0106 seconds to query once, the label is   3

# %%
dist = []
count = []
for i in range(15):
    print("=========================== this is image ",i+1,"==================================")
    print("original label:",labels[i+1])
    mod,queries = attack.attack_untargeted(new_img[i+1],labels[i+1],alpha = 1, beta = 0.01, iterations = 1000)
    dist.append(np.linalg.norm(mod))
    count.append(queries)
    
    
index = np.nonzero(count)
index = list(index)[0].tolist()

avg_distortion = np.mean(np.array(dist)[index])
avg_count = np.mean(np.array(count)[index])
print("the average distortion for %2d images :"%(len(index)),avg_distortion)
print("the distortions for 15 images :")
for i in dist:
    print(i)
    
print("the number of queries for %2d images :"%(len(index)), avg_count)    
print("the number of queries for 15 images :")
for j in count:
    print(j)
# Out:
# =========================== this is image  1 ==================================
# original label: 8
# --------> Found distortion 19.5305 in iterationn 0
# --------> Found distortion 13.2667 in iterationn 1
# --------> Found distortion 11.2359 in iterationn 4
# --------> Found distortion 10.8403 in iterationn 68
# ==========> Found best distortion 10.8403 in 3.2613 seconds using 282 queries
# iteration 1 , distortion 10.8403
# iteration 2 , distortion 10.4176
# iteration 3 , distortion 10.4176
# iteration 4 , distortion 10.3422
# iteration 5 , distortion 10.3366
# iteration 6 , distortion 10.3346
# iteration 7 , distortion 10.3312
# iteration 8 , distortion 10.3301
# thermometer
# best distortion : tensor(10.32923316955566406250)
# number of queries : 3190
# =========================== this is image  2 ==================================
# original label: 8
# --------> Found distortion 10.1889 in iterationn 0
# --------> Found distortion 8.5416 in iterationn 1
# --------> Found distortion 1.4195 in iterationn 2
# --------> Found distortion 1.3884 in iterationn 6
# --------> Found distortion 0.8685 in iterationn 10
# --------> Found distortion 0.7762 in iterationn 19
# --------> Found distortion 0.5851 in iterationn 29
# --------> Found distortion 0.2293 in iterationn 32
# --------> Found distortion 0.1322 in iterationn 49
# --------> Found distortion 0.0949 in iterationn 57
# ==========> Found best distortion 0.0949 in 4.3071 seconds using 368 queries
# iteration 1 , distortion 0.0949
# ============query number after distortion < 2 ==============: 368
# thermometer
# best distortion : tensor(0.09485078603029251099)
# number of queries : 368
# =========================== this is image  3 ==================================
# original label: 0
# --------> Found distortion 13.9896 in iterationn 0
# --------> Found distortion 12.8308 in iterationn 1
# --------> Found distortion 11.1947 in iterationn 3
# --------> Found distortion 8.1729 in iterationn 23
# --------> Found distortion 8.0161 in iterationn 25
# --------> Found distortion 6.0633 in iterationn 75
# ==========> Found best distortion 6.0633 in 3.7256 seconds using 320 queries
# iteration 1 , distortion 6.0633
# iteration 2 , distortion 5.8740
# iteration 3 , distortion 5.7638
# iteration 4 , distortion 5.6706
# iteration 5 , distortion 4.1906
# iteration 6 , distortion 4.1065
# iteration 7 , distortion 4.0741
# iteration 8 , distortion 4.0729
# iteration 9 , distortion 4.0356
# iteration 10 , distortion 4.0117
# iteration 11 , distortion 4.0058
# iteration 12 , distortion 3.9998
# iteration 13 , distortion 3.9956
# iteration 14 , distortion 3.9953
# iteration 15 , distortion 3.9944
# iteration 16 , distortion 3.9907
# iteration 17 , distortion 3.9896
# iteration 18 , distortion 3.9755
# iteration 19 , distortion 3.9750
# iteration 20 , distortion 3.9750
# thermometer
# best distortion : tensor(3.97418069839477539062)
# number of queries : 5728
# =========================== this is image  4 ==================================
# original label: 6
# --------> Found distortion 13.9888 in iterationn 0
# --------> Found distortion 10.0026 in iterationn 1
# --------> Found distortion 7.1680 in iterationn 33
# --------> Found distortion 6.2938 in iterationn 58
# --------> Found distortion 6.0695 in iterationn 60
# --------> Found distortion 4.8419 in iterationn 72
# ==========> Found best distortion 4.8419 in 3.6928 seconds using 318 queries
# iteration 1 , distortion 4.8419
# iteration 2 , distortion 4.5749
# iteration 3 , distortion 4.5118
# iteration 4 , distortion 4.4691
# iteration 5 , distortion 4.3655
# iteration 6 , distortion 3.3355
# iteration 7 , distortion 3.2333
# iteration 8 , distortion 3.0461
# iteration 9 , distortion 2.8307
# iteration 10 , distortion 2.7047
# iteration 11 , distortion 2.6751
# iteration 12 , distortion 2.6749
# iteration 13 , distortion 2.6730
# iteration 14 , distortion 2.6622
# iteration 15 , distortion 2.6622
# iteration 16 , distortion 2.6520
# iteration 17 , distortion 2.6498
# iteration 18 , distortion 2.6466
# iteration 19 , distortion 2.6351
# iteration 20 , distortion 2.6263
# iteration 21 , distortion 2.6223
# iteration 22 , distortion 2.6197
# iteration 23 , distortion 2.6192
# iteration 24 , distortion 2.6166
# iteration 25 , distortion 2.6155
# thermometer
# best distortion : tensor(2.61157345771789550781)
# number of queries : 8089
# =========================== this is image  5 ==================================
# original label: 6
# --------> Found distortion 17.4967 in iterationn 0
# --------> Found distortion 16.8584 in iterationn 37
# --------> Found distortion 16.0912 in iterationn 39
# ==========> Found best distortion 16.0912 in 2.9652 seconds using 256 queries
# iteration 1 , distortion 16.0912
# iteration 2 , distortion 15.3320
# iteration 3 , distortion 15.0244
# iteration 4 , distortion 14.8969
# iteration 5 , distortion 14.7981
# iteration 6 , distortion 14.7388
# iteration 7 , distortion 14.7295
# iteration 8 , distortion 14.5360
# iteration 9 , distortion 14.4553
# iteration 10 , distortion 14.4107
# iteration 11 , distortion 14.4092
# iteration 12 , distortion 14.3778
# iteration 13 , distortion 14.3778
# iteration 14 , distortion 14.3589
# iteration 15 , distortion 14.3451
# iteration 16 , distortion 14.3408
# thermometer
# best distortion : tensor(14.33956527709960937500)
# number of queries : 5042
# =========================== this is image  6 ==================================
# original label: 1
# --------> Found distortion 16.4804 in iterationn 0
# --------> Found distortion 14.7111 in iterationn 2
# --------> Found distortion 13.9171 in iterationn 6
# --------> Found distortion 13.5996 in iterationn 12
# --------> Found distortion 12.8861 in iterationn 14
# --------> Found distortion 12.6305 in iterationn 43
# ==========> Found best distortion 12.6305 in 3.7033 seconds using 322 queries
# iteration 1 , distortion 12.6305
# iteration 2 , distortion 12.6015
# iteration 3 , distortion 12.5353
# iteration 4 , distortion 12.2108
# iteration 5 , distortion 11.8997
# iteration 6 , distortion 11.8629
# iteration 7 , distortion 11.8372
# iteration 8 , distortion 11.7513
# iteration 9 , distortion 11.7180
# iteration 10 , distortion 11.7003
# iteration 11 , distortion 11.6745
# iteration 12 , distortion 11.6559
# iteration 13 , distortion 11.6308
# iteration 14 , distortion 11.6208
# iteration 15 , distortion 11.6202
# iteration 16 , distortion 11.6121
# iteration 17 , distortion 11.5982
# iteration 18 , distortion 11.5911
# iteration 19 , distortion 11.5802
# iteration 20 , distortion 11.5781
# iteration 21 , distortion 11.5730
# iteration 22 , distortion 11.5717
# thermometer
# best distortion : tensor(11.57116508483886718750)
# number of queries : 5626
# =========================== this is image  7 ==================================
# original label: 6
# --------> Found distortion 16.7507 in iterationn 0
# --------> Found distortion 11.1664 in iterationn 1
# --------> Found distortion 11.0450 in iterationn 2
# --------> Found distortion 9.2171 in iterationn 3
# --------> Found distortion 8.5493 in iterationn 7
# --------> Found distortion 7.9102 in iterationn 12
# --------> Found distortion 7.5719 in iterationn 30
# --------> Found distortion 7.4274 in iterationn 36
# --------> Found distortion 1.5407 in iterationn 40
# --------> Found distortion 1.4804 in iterationn 41
# --------> Found distortion 1.2475 in iterationn 47
# --------> Found distortion 1.0576 in iterationn 66
# --------> Found distortion 0.9955 in iterationn 67
# --------> Found distortion 0.9940 in iterationn 86
# ==========> Found best distortion 0.9940 in 5.3734 seconds using 457 queries
# iteration 1 , distortion 0.9940
# ============query number after distortion < 2 ==============: 457
# thermometer
# best distortion : tensor(0.99403393268585205078)
# number of queries : 457
# =========================== this is image  8 ==================================
# original label: 3
# --------> Found distortion 4.2604 in iterationn 0
# --------> Found distortion 3.5577 in iterationn 1
# --------> Found distortion 2.8470 in iterationn 7
# --------> Found distortion 2.7340 in iterationn 40
# --------> Found distortion 2.5509 in iterationn 75
# --------> Found distortion 2.4339 in iterationn 93
# ==========> Found best distortion 2.4339 in 3.6144 seconds using 311 queries
# iteration 1 , distortion 2.4339
# iteration 2 , distortion 2.3834
# iteration 3 , distortion 2.1776
# iteration 4 , distortion 1.7362
# ============query number after distortion < 2 ==============: 981
# thermometer
# best distortion : tensor(1.73616111278533935547)
# number of queries : 981
# =========================== this is image  9 ==================================
# original label: 1
# Fail to classify the image. No need to attack.
# =========================== this is image  10 ==================================
# original label: 0
# --------> Found distortion 7.5105 in iterationn 0
# --------> Found distortion 7.3749 in iterationn 2
# --------> Found distortion 6.2231 in iterationn 3
# --------> Found distortion 6.0347 in iterationn 9
# --------> Found distortion 5.8316 in iterationn 12
# --------> Found distortion 4.9189 in iterationn 41
# ==========> Found best distortion 4.9189 in 3.6137 seconds using 317 queries
# iteration 1 , distortion 4.9189
# iteration 2 , distortion 4.8300
# iteration 3 , distortion 4.6638
# iteration 4 , distortion 4.6196
# iteration 5 , distortion 4.5780
# iteration 6 , distortion 4.5650
# iteration 7 , distortion 4.5574
# iteration 8 , distortion 4.5519
# iteration 9 , distortion 4.5495
# iteration 10 , distortion 4.5490
# iteration 11 , distortion 4.3753
# iteration 12 , distortion 4.3669
# iteration 13 , distortion 4.2967
# iteration 14 , distortion 4.2583
# iteration 15 , distortion 4.2379
# iteration 16 , distortion 4.2343
# iteration 17 , distortion 4.2284
# iteration 18 , distortion 4.2272
# thermometer
# best distortion : tensor(4.18419742584228515625)
# number of queries : 6522
# =========================== this is image  11 ==================================
# original label: 9
# --------> Found distortion 16.6363 in iterationn 0
# --------> Found distortion 14.1749 in iterationn 1
# --------> Found distortion 13.8022 in iterationn 32
# --------> Found distortion 13.7463 in iterationn 49
# ==========> Found best distortion 13.7463 in 3.2762 seconds using 282 queries
# iteration 1 , distortion 13.7463
# iteration 2 , distortion 12.9974
# iteration 3 , distortion 12.7212
# iteration 4 , distortion 12.5594
# iteration 5 , distortion 12.5224
# iteration 6 , distortion 12.5224
# iteration 7 , distortion 12.4498
# iteration 8 , distortion 12.4360
# iteration 9 , distortion 12.4320
# thermometer
# best distortion : tensor(12.43160915374755859375)
# number of queries : 3461
# =========================== this is image  12 ==================================
# original label: 5
# --------> Found distortion 5.9752 in iterationn 0
# --------> Found distortion 5.5077 in iterationn 1
# --------> Found distortion 5.4144 in iterationn 2
# --------> Found distortion 5.0088 in iterationn 3
# --------> Found distortion 2.8225 in iterationn 9
# --------> Found distortion 2.5093 in iterationn 10
# --------> Found distortion 1.9409 in iterationn 18
# --------> Found distortion 1.1925 in iterationn 24
# --------> Found distortion 1.0094 in iterationn 45
# --------> Found distortion 0.9382 in iterationn 46
# --------> Found distortion 0.2900 in iterationn 73
# --------> Found distortion 0.1163 in iterationn 76
# --------> Found distortion 0.0582 in iterationn 83
# --------> Found distortion 0.0535 in iterationn 84
# --------> Found distortion 0.0514 in iterationn 86
# --------> Found distortion 0.0454 in iterationn 87
# --------> Found distortion 0.0404 in iterationn 96
# ==========> Found best distortion 0.0404 in 5.5552 seconds using 472 queries
# iteration 1 , distortion 0.0404
# ============query number after distortion < 2 ==============: 472
# thermometer
# best distortion : tensor(0.04044009000062942505)
# number of queries : 472
# =========================== this is image  13 ==================================
# original label: 7
# --------> Found distortion 19.9534 in iterationn 0
# --------> Found distortion 19.6065 in iterationn 1
# --------> Found distortion 19.0292 in iterationn 6
# --------> Found distortion 18.8363 in iterationn 31
# --------> Found distortion 18.4417 in iterationn 39
# --------> Found distortion 17.2406 in iterationn 57
# ==========> Found best distortion 17.2406 in 3.7249 seconds using 322 queries
# iteration 1 , distortion 17.2406
# iteration 2 , distortion 17.1877
# iteration 3 , distortion 16.7342
# iteration 4 , distortion 16.7324
# iteration 5 , distortion 16.7312
# iteration 6 , distortion 16.7305
# iteration 7 , distortion 16.7216
# iteration 8 , distortion 16.7212
# iteration 9 , distortion 16.7190
# iteration 10 , distortion 16.7122
# thermometer
# best distortion : tensor(16.71014404296875000000)
# number of queries : 3490
# =========================== this is image  14 ==================================
# original label: 9
# --------> Found distortion 14.0912 in iterationn 0
# --------> Found distortion 13.9324 in iterationn 29
# --------> Found distortion 12.3969 in iterationn 43
# ==========> Found best distortion 12.3969 in 2.9850 seconds using 262 queries
# iteration 1 , distortion 12.3969
# iteration 2 , distortion 12.2600
# iteration 3 , distortion 12.2600
# iteration 4 , distortion 12.2480
# iteration 5 , distortion 12.2458
# thermometer
# best distortion : tensor(12.24547481536865234375)
# number of queries : 2936
# =========================== this is image  15 ==================================
# original label: 8
# --------> Found distortion 11.8268 in iterationn 0
# --------> Found distortion 11.1802 in iterationn 2
# --------> Found distortion 11.1715 in iterationn 5
# --------> Found distortion 10.9893 in iterationn 6
# --------> Found distortion 10.9711 in iterationn 13
# --------> Found distortion 10.5757 in iterationn 14
# --------> Found distortion 10.5729 in iterationn 25
# --------> Found distortion 9.2118 in iterationn 26
# ==========> Found best distortion 9.2118 in 4.2052 seconds using 362 queries
# iteration 1 , distortion 9.2118
# iteration 2 , distortion 9.1271
# iteration 3 , distortion 9.0192
# iteration 4 , distortion 8.9062
# iteration 5 , distortion 8.8722
# iteration 6 , distortion 8.4592
# iteration 7 , distortion 8.4510
# iteration 8 , distortion 8.3982
# iteration 9 , distortion 8.3643
# iteration 10 , distortion 8.3559
# iteration 11 , distortion 8.3150
# iteration 12 , distortion 8.2785
# iteration 13 , distortion 8.2677
# iteration 14 , distortion 8.2648
